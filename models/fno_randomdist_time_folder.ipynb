# %% [markdown]
# # FNO Model 3 (Omega + 3 channels, 4 total) 16x16x16 train/val + 64x64x64 test (test data to be generated)
# # FNO model of random folder wise and random timestep distribution for train-test-val.

# %%
# =========================
# Imports and experiment configuration (3D grid training)
# =========================
import glob
import random
import re
import sys
from pathlib import Path
from collections import defaultdict

import numpy as np
import torch
import matplotlib.pyplot as plt
from cycler import cycler
from torch.utils.data import Dataset, DataLoader

from neuralop.models import FNO
from neuralop.losses import LpLoss
from neuralop.utils import count_model_params

# Central config: edit here only.
CFG = {
    # Random seed for reproducibility across numpy/torch/data split steps.
    'seed': 42,
    # Switch for quick preliminary runs before full-scale training.
    'fast_sanity_mode': False,

    # Optional dataset root used for relative paths.
    'data_root': '.',

    # Random folder-holdout + random time sampling.
    # Folders for train/val/test are drawn randomly from split_dirs (seeded),
    # then each split samples random timesteps via file caps.
    'split_mode': 'random_folder_holdout_time',
    'split_dirs': [
        'train/pair_1_fno_32/',
        'train/pair_2_fno_32/',
        'train/pair_3_fno_32/',
        'train/pair_4_fno_32/',
        'train/pair_5_fno_32/',
    ],
    'random_folder_counts': {'train': 3, 'val': 3, 'test': 3},
    'train_dirs': [],
    'val_dirs': [],
    'test_dirs': [],
    # Keep SR disabled for now (can be enabled later).
    'test_sr_dirs': [],
    # Folders used only for visual candidate comparison.
    'candidate_preview_dirs': [
        'train/pair_1_fno_32/',
        'train/pair_2_fno_32/',
        'train/pair_3_fno_32/',
        'train/pair_4_fno_32/',
        'train/pair_5_fno_32/',
    ],

    # Use one folder per split for timeline plotting (same dataset across all 4 snapshots).
    # Leave as None so selected random folders determine the timeline source.
    'preferred_train_folder': None,
    'preferred_val_folder': None,
    'preferred_test_folder': None,

    # Timeline selection settings: 4 distant snapshots, not starting at frame 0.
    'timeline_n_cols': 4,
    'timeline_fractions': [0.18, 0.42, 0.70, 0.92],
    'timeline_start_frac': 0.10,

    # Skip initial frames to avoid startup transient.
    'min_frame_trainval': 10,
    'min_frame_test': 10,
    'min_frame_sr': 10,

    # 3D resolution checks.
    'train_expected_res': 32,
    'test_expected_res': 32,
    'test_sr_expected_res': 'auto',

    # Require a real test split by default.
    'allow_missing_test_dirs': False,

    # Optional file caps for quick sanity runs.
    'max_train_files': 256,
    'max_val_files': 96,
    'max_test_files': 96,
    'max_test_sr_files': None,

    # Spatial subsampling stride in dataset loader.
    'train_grid_stride': 1,
    'val_grid_stride': 1,
    'test_grid_stride': 1,

    # Feature scaling controls (computed from TRAIN split only).
    'normalize_inputs': True,
    'normalize_targets': True,
    'strict_normalization': True,
    'norm_eps': 1e-6,
    'norm_max_files': 192,

    # DataLoader tuning.
    'num_workers': 0,
    'pin_memory': True,
    'prefetch_factor': 2,

    # Training loop diagnostics/shortcuts.
    'log_every_batches': 10,
    'max_batches_per_epoch': None,  # set int for quick sanity runs

    # Optimization.
    'batch_size': 2,
    'epochs': 120,
    'lr': 1e-3,
    'weight_decay': 1e-4,

    # FNO architecture.
    'n_modes': (10, 10, 10),
    'hidden_channels': 64,
    'projection_channel_ratio': 2,

    # Evaluate every N epochs.
    'eval_every': 1,

    # Strict output checks for model inference.
    'strict_output_shape': True,

    # Use best validation checkpoint for all plots/diagnostics.
    'use_best_checkpoint_for_reports': True,

    # Optional diagnostics (disabled to keep workflow focused).
    'enable_optional_plots': False,

    # Plot styling.
    'plot_dpi': 300,
    'use_latex_font_style': True,
    'plot_field_cmap': 'viridis',
    'plot_error_cmap': 'magma',

    # Variant-specific fields.
    'input_channels': 4,
    'input_key': 'input_grid_omega4',
    'file_tag': 'fno_randomdist_time_folder_3d',
}

# Randomly assign folder-disjoint train/val/test sets (seeded) when requested.
if CFG.get('split_mode') == 'random_folder_holdout_time':
    candidate_dirs = list(CFG.get('split_dirs', []))
    if len(candidate_dirs) < 3:
        raise RuntimeError('random_folder_holdout_time requires at least 3 folders in CFG["split_dirs"]')

    counts = dict(CFG.get('random_folder_counts', {'train': 3, 'val': 1, 'test': 1}))
    n_train = int(counts.get('train', max(1, len(candidate_dirs) - 2)))
    n_val = int(counts.get('val', 1))
    n_test = int(counts.get('test', 1))

    total_needed = n_train + n_val + n_test
    if total_needed > len(candidate_dirs):
        # Clamp while preserving at least 1 folder per split.
        n_test = max(1, min(n_test, len(candidate_dirs) - 2))
        n_val = max(1, min(n_val, len(candidate_dirs) - n_test - 1))
        n_train = max(1, len(candidate_dirs) - n_val - n_test)

    rng = np.random.default_rng(int(CFG.get('seed', 42)))
    perm = [candidate_dirs[i] for i in rng.permutation(len(candidate_dirs))]

    CFG['train_dirs'] = perm[:n_train]
    CFG['val_dirs'] = perm[n_train:n_train + n_val]
    CFG['test_dirs'] = perm[n_train + n_val:n_train + n_val + n_test]

    # Align timeline preference with selected random folders.
    CFG['preferred_train_folder'] = Path(CFG['train_dirs'][0]).name if len(CFG['train_dirs']) > 0 else None
    CFG['preferred_val_folder'] = Path(CFG['val_dirs'][0]).name if len(CFG['val_dirs']) > 0 else None
    CFG['preferred_test_folder'] = Path(CFG['test_dirs'][0]).name if len(CFG['test_dirs']) > 0 else None

    print('[info] random folder split selected:', {
        'train_dirs': CFG['train_dirs'],
        'val_dirs': CFG['val_dirs'],
        'test_dirs': CFG['test_dirs'],
    })


def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


set_seed(CFG['seed'])
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
NON_BLOCKING = DEVICE == 'cuda'

if CFG.get('use_latex_font_style', True):
    # Use LaTeX-like style without requiring a TeX install.
    plt.rcParams.update({
        'font.family': 'serif',
        'font.serif': ['Computer Modern Roman', 'Times New Roman', 'DejaVu Serif'],
        'mathtext.fontset': 'cm',
        'text.usetex': False,
        'axes.labelsize': 11,
        'axes.titlesize': 12,
        'xtick.labelsize': 9,
        'ytick.labelsize': 9,
        'legend.fontsize': 9,
        'axes.prop_cycle': cycler(color=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']),
        'figure.facecolor': 'white',
        'axes.facecolor': 'white',
        'image.cmap': CFG.get('plot_field_cmap', 'viridis'),
    })

print('Python executable:', sys.executable)
print('Torch version:', torch.__version__)
print('Torch CUDA build:', torch.version.cuda)
print('CUDA available:', torch.cuda.is_available())
if DEVICE == 'cuda':
    print('Device:', DEVICE, '| GPU:', torch.cuda.get_device_name(0))
    torch.backends.cudnn.benchmark = True
else:
    print('Device:', DEVICE)
    print('[warn] CUDA is not available in this notebook kernel. If gpu_test.py succeeds in fno-env, switch Jupyter to that environment before training.')

print('Variant:', CFG['input_key'], 'channels=', CFG['input_channels'])
print('Split mode:', CFG['split_mode'])
print('Train dirs:', CFG['train_dirs'])
print('Val dirs:', CFG['val_dirs'])
print('Test dirs:', CFG['test_dirs'])
print('Timeline columns:', CFG['timeline_n_cols'], '| fractions:', CFG['timeline_fractions'])
print('Fast sanity mode:', CFG['fast_sanity_mode'])
print('Allow missing test dirs:', CFG['allow_missing_test_dirs'])
print('File caps train/val/test/test_sr:', CFG['max_train_files'], CFG['max_val_files'], CFG['max_test_files'], CFG['max_test_sr_files'])
print('Grid stride train/val/test:', CFG['train_grid_stride'], CFG['val_grid_stride'], CFG['test_grid_stride'])
print('Min frames train/val/test/sr:', CFG['min_frame_trainval'], CFG['min_frame_test'], CFG['min_frame_sr'])
print('Normalize inputs/targets:', CFG['normalize_inputs'], CFG['normalize_targets'])
print('Plot style:', {'field_cmap': CFG['plot_field_cmap'], 'error_cmap': CFG['plot_error_cmap'], 'dpi': CFG['plot_dpi']})

# Apply fast sanity settings (overrides) if enabled.
if CFG.get('fast_sanity_mode'):
    print('[info] FAST_SANITY mode enabled: applying lightweight settings')
    CFG['epochs'] = min(int(CFG.get('epochs', 1)), 5)
    CFG['eval_every'] = max(1, int(CFG.get('eval_every', 1)))
    CFG['max_train_files'] = min(int(CFG.get('max_train_files', 64) or 64), 64)
    CFG['max_val_files'] = min(int(CFG.get('max_val_files', 16) or 16), 16)
    CFG['max_test_files'] = min(int(CFG.get('max_test_files', 16) or 16), 16)
    CFG['max_test_sr_files'] = min(int(CFG.get('max_test_sr_files', 16) or 16), 16)
    CFG['max_batches_per_epoch'] = int(CFG.get('max_batches_per_epoch') or 5)
    CFG['log_every_batches'] = int(CFG.get('log_every_batches') or 5)
    CFG['test_sr_dirs'] = []
    CFG['epochs'] = max(1, CFG['epochs'])
    print('[info] FAST_SANITY settings applied:', {
        'epochs': CFG['epochs'],
        'eval_every': CFG['eval_every'],
        'max_train_files': CFG['max_train_files'],
        'max_val_files': CFG['max_val_files'],
        'max_test_files': CFG['max_test_files'],
        'max_test_sr_files': CFG['max_test_sr_files'],
        'max_batches_per_epoch': CFG['max_batches_per_epoch'],
        'log_every_batches': CFG['log_every_batches'],
        'test_sr_dirs': CFG['test_sr_dirs'],
    })
# Out:
# [info] random folder split selected: {'train_dirs': ['train/pair_5_fno_32/'], 'val_dirs': ['train/pair_3_fno_32/'], 'test_dirs': ['train/pair_4_fno_32/', 'train/pair_2_fno_32/', 'train/pair_1_fno_32/']}
# Python executable: c:\Users\TCZ\Desktop\Neeraj\Flow-reconstruction-in-VPM-using-FNO-main\fno-env\Scripts\python.exe
# Torch version: 2.6.0+cu124
# Torch CUDA build: 12.4
# CUDA available: True
# Device: cuda | GPU: NVIDIA RTX 4000 Ada Generation
# Variant: input_grid_omega4 channels= 4
# Split mode: random_folder_holdout_time
# Train dirs: ['train/pair_5_fno_32/']
# Val dirs: ['train/pair_3_fno_32/']
# Test dirs: ['train/pair_4_fno_32/', 'train/pair_2_fno_32/', 'train/pair_1_fno_32/']
# Timeline columns: 4 | fractions: [0.18, 0.42, 0.7, 0.92]
# Fast sanity mode: False
# Allow missing test dirs: False
# File caps train/val/test/test_sr: 256 96 96 None
# Grid stride train/val/test: 1 1 1
# Min frames train/val/test/sr: 10 10 10
# Normalize inputs/targets: True True
# Plot style: {'field_cmap': 'viridis', 'error_cmap': 'magma', 'dpi': 300}

# %%
# =========================
# Data setup (3D train/val/test) + normalization
# =========================
cwd = Path.cwd().resolve()
if (cwd / '.git').exists():
    REPO_ROOT = cwd
elif (cwd.parent / '.git').exists():
    REPO_ROOT = cwd.parent
else:
    REPO_ROOT = cwd

data_root_cfg = CFG.get('data_root')
if data_root_cfg in (None, '', '.'):
    DATA_ROOT = REPO_ROOT
else:
    data_root_path = Path(data_root_cfg).expanduser()
    if data_root_path.is_absolute():
        DATA_ROOT = data_root_path.resolve()
    else:
        # Resolve relative data_root from repo root, not notebook cwd.
        DATA_ROOT = (REPO_ROOT / data_root_path).resolve()

print('Detected REPO_ROOT:', REPO_ROOT)
print('DATA_ROOT:', DATA_ROOT)

RESULTS_DIR = REPO_ROOT / 'results'
RESULTS_DIR.mkdir(parents=True, exist_ok=True)
print('Results directory:', RESULTS_DIR)

ALLOW_MISSING_TEST = bool(CFG.get('allow_missing_test_dirs')) or bool(CFG.get('fast_sanity_mode'))


def save_fig(fig, filename, dpi=None):
    dpi_use = int(dpi or CFG.get('plot_dpi', 300))
    out = RESULTS_DIR / f"{CFG['file_tag']}_{filename}"
    fig.savefig(out, dpi=dpi_use, bbox_inches='tight')
    print(f'[saved] {out}')


def resolve_dirs(path_list, must_exist=True, base_root=DATA_ROOT):
    dirs = []
    for d in path_list:
        p = Path(d).expanduser()
        if p.is_absolute():
            candidates = [p.resolve()]
        else:
            candidates = [(base_root / p).resolve()]
            # Fallback to repo-root relative path to avoid cwd-dependent failures.
            repo_candidate = (REPO_ROOT / p).resolve()
            if repo_candidate not in candidates:
                candidates.append(repo_candidate)

        found = next((c for c in candidates if c.is_dir()), None)
        if found is not None:
            dirs.append(found)
            continue

        if must_exist:
            tried = ' | '.join(str(c) for c in candidates)
            raise FileNotFoundError(f'Missing directory: {p}. Tried: {tried}')
        else:
            print(f'[warn] directory missing, skipping: {candidates[0]}')
    return dirs


TRAIN_DIRS = resolve_dirs(CFG.get('train_dirs', []), must_exist=True)
VAL_DIRS = resolve_dirs(CFG.get('val_dirs', []), must_exist=True)
TEST_DIRS = resolve_dirs(CFG.get('test_dirs', []), must_exist=not ALLOW_MISSING_TEST)
TEST_SR_DIRS = resolve_dirs(CFG.get('test_sr_dirs', []), must_exist=False)
PREVIEW_DIRS = resolve_dirs(CFG.get('candidate_preview_dirs', []), must_exist=False)

if len(TRAIN_DIRS) == 0:
    raise RuntimeError('No train directories configured. Fill CFG["train_dirs"].')
if len(VAL_DIRS) == 0:
    raise RuntimeError('No validation directories configured. Fill CFG["val_dirs"].')
if not ALLOW_MISSING_TEST and len(TEST_DIRS) == 0 and len(TEST_SR_DIRS) == 0:
    raise RuntimeError('No test/test_sr dirs provided and allow_missing_test_dirs=False')


FRAME_RE = re.compile(r'frame_(\d+)', re.IGNORECASE)


def parse_frame_id(path_like):
    name = Path(path_like).name
    m = FRAME_RE.search(name)
    if not m:
        raise ValueError(f'Cannot parse frame id from filename: {name}')
    return int(m.group(1))


def list_frame_files(sim_dir, expect_gridded=True):
    grid_files = sorted(
        glob.glob(str(sim_dir / 'frame_*_grid.npz')),
        key=parse_frame_id,
    )
    if grid_files:
        return grid_files

    raw_files = sorted(
        glob.glob(str(sim_dir / 'frame_*.npz')),
        key=parse_frame_id,
    )

    if raw_files and expect_gridded:
        sample = np.load(raw_files[0])
        raise RuntimeError(
            f"Directory {sim_dir} has raw frame_*.npz ({len(raw_files)} files) but no frame_*_grid.npz. "
            f"Sample keys: {list(sample.files)}. "
            "This notebook expects gridded data with U_grid/input_grid_* keys. "
            "Run dataset_gen/autodomain_particle_grid.py and point CFG train/test dirs to pair_*_fno* folders."
        )

    return raw_files


def gridded_file_is_valid(file_path, input_key, expected_channels):
    if Path(file_path).stat().st_size == 0:
        return False, 'empty_file'

    try:
        d = np.load(file_path)
    except Exception as exc:
        return False, f'load_error: {exc}'

    if input_key not in d:
        return False, f"missing_input_key:{input_key}"
    if 'U_grid' not in d:
        return False, 'missing_output_key:U_grid'

    x = np.asarray(d[input_key], dtype=np.float32)
    y = np.asarray(d['U_grid'], dtype=np.float32)

    if x.ndim != 4 or y.ndim != 4:
        return False, f'bad_rank:x{tuple(x.shape)}_y{tuple(y.shape)}'
    if x.shape[0] != expected_channels:
        return False, f'bad_input_channels:{x.shape[0]}!=exp{expected_channels}'
    if y.shape[0] != 3:
        return False, f'bad_output_channels:{y.shape[0]}'
    if x.shape[-3:] != y.shape[-3:]:
        return False, f'res_mismatch:x{tuple(x.shape[-3:])}_y{tuple(y.shape[-3:])}'

    if not np.isfinite(x).all():
        return False, 'non_finite_input'
    if not np.isfinite(y).all():
        return False, 'non_finite_output'

    return True, 'ok'


def filter_valid_gridded_files(files, input_key, expected_channels, label, max_report=5):
    valid = []
    dropped = []
    for fp in files:
        ok, reason = gridded_file_is_valid(fp, input_key=input_key, expected_channels=expected_channels)
        if ok:
            valid.append(fp)
        else:
            dropped.append((fp, reason))

    if dropped:
        print(f"[warn] {label}: dropped {len(dropped)} invalid files")
        for fp, reason in dropped[:max_report]:
            print(f"    - {Path(fp).name}: {reason}")
        if len(dropped) > max_report:
            print(f"    ... and {len(dropped) - max_report} more")

    return valid


def filter_by_min_frame(files, min_frame, label):
    if min_frame in (None, 0):
        return files
    kept = [f for f in files if parse_frame_id(f) >= min_frame]
    if len(kept) != len(files):
        print(f"[info] {label} frame filter: kept {len(kept)}/{len(files)} with frame >= {min_frame}")
    return kept


def collect_files_from_dirs(dirs, split_label, min_frame):
    all_files = []
    per_dir_counts = {}
    for d in dirs:
        files = list_frame_files(d, expect_gridded=True)
        if len(files) == 0:
            print(f"[warn] no frame files found in {split_label} dir: {d}")
            continue

        files = filter_valid_gridded_files(
            files,
            input_key=CFG['input_key'],
            expected_channels=CFG['input_channels'],
            label=f"{d.name} ({split_label})",
        )
        files = filter_by_min_frame(files, min_frame, f"{d.name} ({split_label})")
        all_files.extend(files)
        per_dir_counts[d.name] = len(files)
        print(f"[info] {split_label} {d.name}: valid_total={len(files)}")
    return all_files, per_dir_counts


TRAIN_FILES, TRAIN_COUNTS = collect_files_from_dirs(TRAIN_DIRS, 'train', CFG['min_frame_trainval'])
VAL_FILES, VAL_COUNTS = collect_files_from_dirs(VAL_DIRS, 'val', CFG['min_frame_trainval'])
TEST_FILES, TEST_COUNTS = collect_files_from_dirs(TEST_DIRS, 'test', CFG['min_frame_test'])
TEST_SR_FILES, TEST_SR_COUNTS = collect_files_from_dirs(TEST_SR_DIRS, 'test_sr', CFG['min_frame_sr'])

HAS_TEST = len(TEST_FILES) > 0
HAS_TEST_SR = len(TEST_SR_FILES) > 0

if len(TRAIN_FILES) == 0:
    raise RuntimeError("No training files found after directory scan/filtering. Check CFG['train_dirs'].")
if len(VAL_FILES) == 0:
    raise RuntimeError("Validation set is empty after filtering. Check CFG['val_dirs'].")
if not ALLOW_MISSING_TEST and not HAS_TEST and not HAS_TEST_SR:
    raise RuntimeError("Test split is empty but allow_missing_test_dirs=False.")


def folder_names(files):
    return {Path(f).parent.name for f in files}


train_folders = folder_names(TRAIN_FILES)
val_folders = folder_names(VAL_FILES)
test_folders = folder_names(TEST_FILES)

if len(train_folders.intersection(val_folders)) > 0:
    raise RuntimeError(f'Train/val folder overlap detected: {sorted(train_folders.intersection(val_folders))}')
if len(train_folders.intersection(test_folders)) > 0:
    raise RuntimeError(f'Train/test folder overlap detected: {sorted(train_folders.intersection(test_folders))}')
if len(val_folders.intersection(test_folders)) > 0:
    raise RuntimeError(f'Val/test folder overlap detected: {sorted(val_folders.intersection(test_folders))}')

print('[info] split folders -> train:', sorted(train_folders), '| val:', sorted(val_folders), '| test:', sorted(test_folders))


def cap_files(files, cap, seed_shift, label):
    if not cap or len(files) <= cap:
        return files
    rng = np.random.default_rng(CFG['seed'] + seed_shift)
    idx = rng.choice(len(files), size=cap, replace=False)
    capped = [files[i] for i in sorted(idx.tolist())]
    print(f"[info] {label} file cap active: using {len(capped)} files")
    return capped


TRAIN_FILES = cap_files(TRAIN_FILES, CFG.get('max_train_files'), 1101, 'train')
VAL_FILES = cap_files(VAL_FILES, CFG.get('max_val_files'), 1201, 'val')
TEST_FILES = cap_files(TEST_FILES, CFG.get('max_test_files'), 1301, 'test')
TEST_SR_FILES = cap_files(TEST_SR_FILES, CFG.get('max_test_sr_files'), 1401, 'test_sr')

TRAIN_FILES = filter_by_min_frame(TRAIN_FILES, CFG['min_frame_trainval'], 'TRAIN_FILES (post)')
VAL_FILES = filter_by_min_frame(VAL_FILES, CFG['min_frame_trainval'], 'VAL_FILES (post)')
TEST_FILES = filter_by_min_frame(TEST_FILES, CFG['min_frame_test'], 'TEST_FILES (post)')
TEST_SR_FILES = filter_by_min_frame(TEST_SR_FILES, CFG['min_frame_sr'], 'TEST_SR_FILES (post)')

HAS_TEST = len(TEST_FILES) > 0
HAS_TEST_SR = len(TEST_SR_FILES) > 0


def summarize_frame_range(files, label):
    if len(files) == 0:
        print(f'[{label}] no files')
        return
    frames = [parse_frame_id(f) for f in files]
    print(f'[{label}] frame range: {min(frames)}..{max(frames)} (n={len(frames)})')


def summarize_per_folder(files, label):
    c = defaultdict(int)
    for f in files:
        c[Path(f).parent.name] += 1
    print(f'[{label}] folder counts:', dict(sorted(c.items())))


print(f"Train files: {len(TRAIN_FILES)} | Val files: {len(VAL_FILES)} | Test files: {len(TEST_FILES)}")
print(f"Test SR files: {len(TEST_SR_FILES)}")
summarize_frame_range(TRAIN_FILES, 'TRAIN')
summarize_frame_range(VAL_FILES, 'VAL')
if HAS_TEST:
    summarize_frame_range(TEST_FILES, 'TEST')
if HAS_TEST_SR:
    summarize_frame_range(TEST_SR_FILES, 'TEST_SR')
summarize_per_folder(TRAIN_FILES, 'TRAIN')
summarize_per_folder(VAL_FILES, 'VAL')
if HAS_TEST:
    summarize_per_folder(TEST_FILES, 'TEST')


def preview_index_map(files, label, max_items=8):
    print(f"[{label}] index preview (first {min(len(files), max_items)} entries)")
    for i, fp in enumerate(files[:max_items]):
        pp = Path(fp)
        print(f"  idx={i:03d} folder={pp.parent.name} frame={parse_frame_id(fp)} file={pp.name}")


preview_index_map(TRAIN_FILES, 'TRAIN')
preview_index_map(VAL_FILES, 'VAL')
if HAS_TEST:
    preview_index_map(TEST_FILES, 'TEST')
if HAS_TEST_SR:
    preview_index_map(TEST_SR_FILES, 'TEST_SR')


def load_x(data):
    key = CFG['input_key']
    if key not in data:
        raise KeyError(f"Missing key '{key}'. Available: {data.files}")
    x = np.asarray(data[key], dtype=np.float32)
    return x


def infer_expected_res(file_path):
    d = np.load(file_path)
    x = load_x(d)
    if x.ndim >= 4:
        return int(x.shape[-1])
    return None


def resolve_expected_res(files, expected_res, label):
    if len(files) == 0:
        return expected_res
    actual = infer_expected_res(files[0])
    if expected_res in (None, 'auto'):
        print(f"[info] {label} expected_res auto-set to {actual}")
        return actual
    if actual is not None and actual != expected_res:
        print(f"[warn] {label} expected_res={expected_res} but data shows {actual}; using data value")
        return actual
    return expected_res


def assert_shapes(files, expected_channels, expected_res=None, label='set'):
    if len(files) == 0:
        return

    bad = []
    for f in files:
        d = np.load(f)
        x = load_x(d)
        y = np.asarray(d['U_grid'], dtype=np.float32)

        ok_channels = (x.shape[0] == expected_channels and y.shape[0] == 3)
        ok_rank = (x.ndim == 4 and y.ndim == 4)

        ok_res = True
        if expected_res is not None:
            ok_res = (
                x.shape[-3:] == (expected_res, expected_res, expected_res)
                and y.shape[-3:] == (expected_res, expected_res, expected_res)
            )

        if not (ok_channels and ok_rank and ok_res):
            bad.append((f, tuple(x.shape), tuple(y.shape)))
            if len(bad) >= 5:
                break

    if bad:
        msg = '\n'.join([f"{fp} -> x:{xs}, y:{ys}" for fp, xs, ys in bad])
        raise RuntimeError(f"{label} shape check failed. Examples:\n{msg}")


def assert_no_overlap(a, b, label_a='A', label_b='B'):
    inter = set(a).intersection(set(b))
    if inter:
        raise RuntimeError(f'{label_a}/{label_b} leakage detected with {len(inter)} overlapping files')


assert_no_overlap(TRAIN_FILES, VAL_FILES, 'train', 'val')
assert_no_overlap(TRAIN_FILES, TEST_FILES, 'train', 'test')
assert_no_overlap(VAL_FILES, TEST_FILES, 'val', 'test')

train_res = resolve_expected_res(TRAIN_FILES, CFG['train_expected_res'], 'train')
val_res = resolve_expected_res(VAL_FILES, CFG['train_expected_res'], 'val')
if HAS_TEST:
    test_res = resolve_expected_res(TEST_FILES, CFG['test_expected_res'], 'test')
else:
    test_res = CFG['test_expected_res']

CFG['train_expected_res'] = train_res
CFG['test_expected_res'] = test_res
if HAS_TEST_SR:
    test_sr_res = resolve_expected_res(TEST_SR_FILES, CFG.get('test_sr_expected_res', 'auto'), 'test_sr')
    CFG['test_sr_expected_res'] = test_sr_res
else:
    test_sr_res = CFG.get('test_sr_expected_res', None)

assert_shapes(TRAIN_FILES, expected_channels=CFG['input_channels'], expected_res=train_res, label='train')
assert_shapes(VAL_FILES, expected_channels=CFG['input_channels'], expected_res=val_res, label='val')
if HAS_TEST:
    assert_shapes(TEST_FILES, expected_channels=CFG['input_channels'], expected_res=test_res, label='test')
if HAS_TEST_SR:
    assert_shapes(TEST_SR_FILES, expected_channels=CFG['input_channels'], expected_res=test_sr_res, label='test_sr')


class Standardizer:
    def __init__(self, mean_x, std_x, mean_y, std_y, eps=1e-6):
        self.mean_x = mean_x
        self.std_x = std_x
        self.mean_y = mean_y
        self.std_y = std_y
        self.eps = eps

    def _reshape_like(self, stats, x):
        # Broadcast channel stats across spatial dims of x and keep them on
        # the same device/dtype as the working tensor.
        stats_t = torch.as_tensor(stats, dtype=x.dtype, device=x.device)
        if x.ndim == 4:
            # x: (C, Nx, Ny, Nz)
            return stats_t[:, None, None, None]
        if x.ndim == 5:
            # x: (B, C, Nx, Ny, Nz)
            return stats_t[None, :, None, None, None]
        raise RuntimeError(f'Unsupported tensor rank for normalization: {x.ndim}')

    def normalize_x(self, x):
        mean = self._reshape_like(self.mean_x, x)
        std = self._reshape_like(self.std_x, x)
        return (x - mean) / std

    def normalize_y(self, y):
        mean = self._reshape_like(self.mean_y, y)
        std = self._reshape_like(self.std_y, y)
        return (y - mean) / std

    def denormalize_y(self, y):
        mean = self._reshape_like(self.mean_y, y)
        std = self._reshape_like(self.std_y, y)
        return y * std + mean


def compute_channel_stats(files, key, nmax, stride, expected_channels, eps):
    files = list(files)
    if len(files) == 0:
        raise RuntimeError('No files provided for normalization stats')

    rng = np.random.default_rng(CFG['seed'])
    if nmax is not None and len(files) > nmax:
        idx = rng.choice(len(files), size=nmax, replace=False)
        files = [files[i] for i in idx]

    sum_c = np.zeros(expected_channels, dtype=np.float64)
    sumsq_c = np.zeros(expected_channels, dtype=np.float64)
    count = 0

    for fp in files:
        d = np.load(fp)
        arr = np.asarray(d[key], dtype=np.float32)
        if stride and stride > 1:
            arr = arr[:, ::stride, ::stride, ::stride]
        if arr.shape[0] != expected_channels:
            raise RuntimeError(f'Channel mismatch in {fp}: got {arr.shape[0]}, expected {expected_channels}')
        arr = arr.reshape(expected_channels, -1)
        sum_c += arr.sum(axis=1)
        sumsq_c += (arr ** 2).sum(axis=1)
        count += arr.shape[1]

    mean = sum_c / max(count, 1)
    var = sumsq_c / max(count, 1) - mean ** 2
    std = np.sqrt(np.maximum(var, eps ** 2))
    return mean.astype(np.float32), std.astype(np.float32)


if CFG['normalize_inputs'] or CFG['normalize_targets']:
    mean_x, std_x = compute_channel_stats(
        TRAIN_FILES,
        key=CFG['input_key'],
        nmax=CFG['norm_max_files'],
        stride=CFG['train_grid_stride'],
        expected_channels=CFG['input_channels'],
        eps=CFG['norm_eps'],
    )
    mean_y, std_y = compute_channel_stats(
        TRAIN_FILES,
        key='U_grid',
        nmax=CFG['norm_max_files'],
        stride=CFG['train_grid_stride'],
        expected_channels=3,
        eps=CFG['norm_eps'],
    )
    NORMALIZER = Standardizer(mean_x, std_x, mean_y, std_y, eps=CFG['norm_eps'])
else:
    NORMALIZER = None

if CFG['strict_normalization'] and (CFG['normalize_inputs'] or CFG['normalize_targets']) and NORMALIZER is None:
    raise RuntimeError('Normalization requested but NORMALIZER is None')


def normalize_input_tensor(x):
    if not CFG['normalize_inputs']:
        return x
    if NORMALIZER is None:
        raise RuntimeError('normalize_inputs=True but NORMALIZER is None')
    return NORMALIZER.normalize_x(x)


def normalize_target_tensor(y):
    if not CFG['normalize_targets']:
        return y
    if NORMALIZER is None:
        raise RuntimeError('normalize_targets=True but NORMALIZER is None')
    return NORMALIZER.normalize_y(y)


def denormalize_target_tensor(y):
    if not CFG['normalize_targets']:
        return y
    if NORMALIZER is None:
        raise RuntimeError('normalize_targets=True but NORMALIZER is None')
    return NORMALIZER.denormalize_y(y)


class GridDataset(Dataset):
    def __init__(self, files, grid_stride=1):
        self.files = list(files)
        self.grid_stride = 1 if grid_stride is None else int(grid_stride)

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        d = np.load(self.files[idx])
        x = torch.tensor(load_x(d), dtype=torch.float32)
        y = torch.tensor(np.asarray(d['U_grid'], dtype=np.float32), dtype=torch.float32)

        s = self.grid_stride
        if s > 1:
            x = x[:, ::s, ::s, ::s]
            y = y[:, ::s, ::s, ::s]

        x = normalize_input_tensor(x)
        y = normalize_target_tensor(y)
        return x, y


TRAIN_DS = GridDataset(TRAIN_FILES, grid_stride=CFG['train_grid_stride'])
VAL_DS = GridDataset(VAL_FILES, grid_stride=CFG['val_grid_stride'])
TEST_DS = GridDataset(TEST_FILES, grid_stride=CFG['test_grid_stride']) if HAS_TEST else None
TEST_SR_DS = GridDataset(TEST_SR_FILES, grid_stride=CFG['test_grid_stride']) if HAS_TEST_SR else None

if HAS_TEST_SR and CFG['test_grid_stride'] not in (None, 1):
    print('[warn] test_grid_stride is set; SR evaluation will be downsampled')

drop_last = len(TRAIN_DS) >= CFG['batch_size']
DL_KW = {
    'num_workers': int(CFG.get('num_workers', 0)),
    'pin_memory': bool(CFG.get('pin_memory', False)) and DEVICE == 'cuda',
    'persistent_workers': int(CFG.get('num_workers', 0)) > 0,
}
if DL_KW['num_workers'] > 0:
    DL_KW['prefetch_factor'] = int(CFG.get('prefetch_factor', 2))

TRAIN_LOADER = DataLoader(TRAIN_DS, batch_size=CFG['batch_size'], shuffle=True, drop_last=drop_last, **DL_KW)
VAL_LOADER = DataLoader(VAL_DS, batch_size=CFG['batch_size'], shuffle=False, **DL_KW)
TEST_LOADER = DataLoader(TEST_DS, batch_size=CFG['batch_size'], shuffle=False, **DL_KW) if HAS_TEST else None
TEST_SR_LOADER = DataLoader(TEST_SR_DS, batch_size=CFG['batch_size'], shuffle=False, **DL_KW) if HAS_TEST_SR else None
print('DataLoader kwargs:', DL_KW)

xtr, ytr = TRAIN_DS[0]
xva, yva = VAL_DS[0]
print('Train sample shape:', tuple(xtr.shape), tuple(ytr.shape))
print('Val sample shape  :', tuple(xva.shape), tuple(yva.shape))
if HAS_TEST:
    xte, yte = TEST_DS[0]
    print('Test sample shape :', tuple(xte.shape), tuple(yte.shape))
    print('First TEST file   :', Path(TEST_FILES[0]).name)
elif len(CFG.get('test_dirs', [])) > 0:
    print('Test sample shape : [unavailable] no valid files loaded from test_dirs')
if HAS_TEST_SR:
    xsr, ysr = TEST_SR_DS[0]
    print('Test SR sample shape:', tuple(xsr.shape), tuple(ysr.shape))
# Out:
# Detected REPO_ROOT: C:\Users\TCZ\Desktop\Neeraj\Flow-reconstruction-in-VPM-using-FNO-main
# DATA_ROOT: C:\Users\TCZ\Desktop\Neeraj\Flow-reconstruction-in-VPM-using-FNO-main
# Results directory: C:\Users\TCZ\Desktop\Neeraj\Flow-reconstruction-in-VPM-using-FNO-main\results
# [warn] pair_5_fno_32 (train): dropped 1 invalid files
#     - frame_0_grid.npz: non_finite_output
# [info] pair_5_fno_32 (train) frame filter: kept 175/179 with frame >= 10
# [info] train pair_5_fno_32: valid_total=175
# [warn] pair_3_fno_32 (val): dropped 1 invalid files
#     - frame_0_grid.npz: non_finite_output
# [info] pair_3_fno_32 (val) frame filter: kept 358/359 with frame >= 10
# [info] val pair_3_fno_32: valid_total=358
# [warn] pair_4_fno_32 (test): dropped 1 invalid files
#     - frame_0_grid.npz: non_finite_output
# [info] pair_4_fno_32 (test) frame filter: kept 198/199 with frame >= 10
# [info] test pair_4_fno_32: valid_total=198
# [warn] pair_2_fno_32 (test): dropped 1 invalid files
#     - frame_0_grid.npz: non_finite_output
# [info] pair_2_fno_32 (test) frame filter: kept 191/200 with frame >= 10
# [info] test pair_2_fno_32: valid_total=191
# [warn] pair_1_fno_32 (test): dropped 1 invalid files
#     - frame_0_grid.npz: non_finite_output
# [info] pair_1_fno_32 (test) frame filter: kept 190/199 with frame >= 10
# [info] test pair_1_fno_32: valid_total=190
# [info] split folders -> train: ['pair_5_fno_32'] | val: ['pair_3_fno_32'] | test: ['pair_1_fno_32', 'pair_2_fno_32', 'pair_4_fno_32']
# [info] val file cap active: using 96 files
# [info] test file cap active: using 96 files
# Train files: 175 | Val files: 96 | Test files: 96
# Test SR files: 0
# [TRAIN] frame range: 10..358 (n=175)
# [VAL] frame range: 35..1795 (n=96)
# [TEST] frame range: 10..975 (n=96)
# [TRAIN] folder counts: {'pair_5_fno_32': 175}
# [VAL] folder counts: {'pair_3_fno_32': 96}
# [TEST] folder counts: {'pair_1_fno_32': 39, 'pair_2_fno_32': 31, 'pair_4_fno_32': 26}
# [TRAIN] index preview (first 8 entries)
#   idx=000 folder=pair_5_fno_32 frame=10 file=frame_10_grid.npz
#   idx=001 folder=pair_5_fno_32 frame=12 file=frame_12_grid.npz
#   idx=002 folder=pair_5_fno_32 frame=14 file=frame_14_grid.npz
#   idx=003 folder=pair_5_fno_32 frame=16 file=frame_16_grid.npz
#   idx=004 folder=pair_5_fno_32 frame=18 file=frame_18_grid.npz
#   idx=005 folder=pair_5_fno_32 frame=20 file=frame_20_grid.npz
#   idx=006 folder=pair_5_fno_32 frame=22 file=frame_22_grid.npz
#   idx=007 folder=pair_5_fno_32 frame=24 file=frame_24_grid.npz
# [VAL] index preview (first 8 entries)
#   idx=000 folder=pair_3_fno_32 frame=35 file=frame_35_grid.npz
#   idx=001 folder=pair_3_fno_32 frame=95 file=frame_95_grid.npz
#   idx=002 folder=pair_3_fno_32 frame=135 file=frame_135_grid.npz
#   idx=003 folder=pair_3_fno_32 frame=155 file=frame_155_grid.npz
#   idx=004 folder=pair_3_fno_32 frame=160 file=frame_160_grid.npz
#   idx=005 folder=pair_3_fno_32 frame=190 file=frame_190_grid.npz
#   idx=006 folder=pair_3_fno_32 frame=200 file=frame_200_grid.npz
#   idx=007 folder=pair_3_fno_32 frame=210 file=frame_210_grid.npz
# [TEST] index preview (first 8 entries)
#   idx=000 folder=pair_4_fno_32 frame=15 file=frame_15_grid.npz
#   idx=001 folder=pair_4_fno_32 frame=35 file=frame_35_grid.npz
#   idx=002 folder=pair_4_fno_32 frame=125 file=frame_125_grid.npz
#   idx=003 folder=pair_4_fno_32 frame=135 file=frame_135_grid.npz
#   idx=004 folder=pair_4_fno_32 frame=185 file=frame_185_grid.npz
#   idx=005 folder=pair_4_fno_32 frame=210 file=frame_210_grid.npz
#   idx=006 folder=pair_4_fno_32 frame=280 file=frame_280_grid.npz
#   idx=007 folder=pair_4_fno_32 frame=300 file=frame_300_grid.npz
# DataLoader kwargs: {'num_workers': 0, 'pin_memory': True, 'persistent_workers': False}
# Train sample shape: (4, 32, 32, 32) (3, 32, 32, 32)
# Val sample shape  : (4, 32, 32, 32) (3, 32, 32, 32)
# Test sample shape : (4, 32, 32, 32) (3, 32, 32, 32)
# First TEST file   : frame_15_grid.npz

# %%
# =========================
# 3D FNO model + optimizer + metrics
# =========================
def build_model(cfg):
    return FNO(
        n_modes=cfg['n_modes'],
        in_channels=cfg['input_channels'],
        out_channels=3,
        hidden_channels=cfg['hidden_channels'],
        projection_channel_ratio=cfg['projection_channel_ratio'],
    ).to(DEVICE)


MODEL = build_model(CFG)

total_params = count_model_params(MODEL)
trainable_params = sum(p.numel() for p in MODEL.parameters() if p.requires_grad)
print('Total params:', total_params)
print('Trainable params:', trainable_params)

OPT = torch.optim.AdamW(MODEL.parameters(), lr=CFG['lr'], weight_decay=CFG['weight_decay'])
SCH = torch.optim.lr_scheduler.CosineAnnealingLR(OPT, T_max=CFG['epochs'])
LOSS_FN = LpLoss(d=3, p=2)


def predict(model, x, expected_shape=None):
    y = model(x)
    if expected_shape is not None and y.shape != expected_shape:
        raise RuntimeError(f'Prediction shape {tuple(y.shape)} != expected {tuple(expected_shape)}')
    return y


def to_physical_y(t):
    # Convert model-space target/prediction tensors back to physical units for metrics/plots.
    return denormalize_target_tensor(t)


def batch_metrics(pred, target):
    if CFG['strict_output_shape'] and pred.shape != target.shape:
        raise RuntimeError(f'Output shape {tuple(pred.shape)} does not match target {tuple(target.shape)}')

    pred_phys = to_physical_y(pred)
    target_phys = to_physical_y(target)

    diff = pred_phys - target_phys
    mse = torch.mean(diff ** 2, dim=(1, 2, 3, 4))
    mae = torch.mean(torch.abs(diff), dim=(1, 2, 3, 4))
    rmse = torch.sqrt(mse)

    diff_flat = diff.reshape(diff.shape[0], -1)
    tgt_flat = target_phys.reshape(target_phys.shape[0], -1)
    rel_l2 = torch.linalg.norm(diff_flat, dim=1) / torch.linalg.norm(tgt_flat, dim=1).clamp_min(1e-12)

    return {
        'mse': mse.mean().item(),
        'mae': mae.mean().item(),
        'rmse': rmse.mean().item(),
        'rel_l2': rel_l2.mean().item(),
        'mse_sum': mse.sum().item(),
        'mae_sum': mae.sum().item(),
        'rmse_sum': rmse.sum().item(),
        'rel_l2_sum': rel_l2.sum().item(),
        'n': mse.shape[0],
        'rel_vec': rel_l2.detach().cpu().numpy(),
    }


@torch.no_grad()
def evaluate(model, loader, collect=False):
    if loader is None:
        return None

    model.eval()
    acc_sum = {'mse': 0.0, 'mae': 0.0, 'rmse': 0.0, 'rel_l2': 0.0}
    rels = []
    total_n = 0

    for x, y in loader:
        x = x.to(DEVICE, non_blocking=NON_BLOCKING)
        y = y.to(DEVICE, non_blocking=NON_BLOCKING)
        pred = predict(model, x, expected_shape=y.shape)
        m = batch_metrics(pred, y)
        for k in acc_sum:
            acc_sum[k] += m[f'{k}_sum']
        if collect:
            rels.extend(m['rel_vec'].tolist())
        total_n += m['n']

    if total_n == 0:
        return None

    acc = {k: acc_sum[k] / max(total_n, 1) for k in acc_sum}
    if collect:
        acc['rel_per_sample'] = np.asarray(rels, dtype=np.float32)
    return acc


def verify_sr_sample():
    if not HAS_TEST_SR:
        return
    xsr, ysr = TEST_SR_DS[0]
    with torch.no_grad():
        pred = predict(MODEL, xsr.unsqueeze(0).to(DEVICE, non_blocking=NON_BLOCKING), expected_shape=ysr.unsqueeze(0).shape)
    print('[verify_sr] input shape:', tuple(xsr.shape), 'target shape:', tuple(ysr.shape), 'pred shape:', tuple(pred.shape))


verify_sr_sample()
# Out:
# Total params: 19712451
# Trainable params: 9882051

# %%
# =========================
import time
# Training loop (3D low-res train/val + optional test/test_sr)
# =========================
HIST = {
    'epoch': [],
    # LpLoss value in normalized target space (optimization objective).
    'train_lp': [],
    # Relative L2 in physical units for easier interpretation.
    'train_rel_l2': [],
    'val_rel_l2': [],
    'val_rmse': [],
    'test_rel_l2': [],
    'test_rmse': [],
    'test_sr_rel_l2': [],
    'test_sr_rmse': [],
    'lr': [],
}

best_val = float('inf')
CKPT_PATH = RESULTS_DIR / f"{CFG['file_tag']}_best_model.pt"

for epoch in range(1, CFG['epochs'] + 1):
    MODEL.train()
    run_loss = 0.0
    run_rel = 0.0
    nb = 0
    t_epoch = time.time()

    for b_idx, (x, y) in enumerate(TRAIN_LOADER, start=1):
        x = x.to(DEVICE, non_blocking=NON_BLOCKING)
        y = y.to(DEVICE, non_blocking=NON_BLOCKING)
        OPT.zero_grad(set_to_none=True)
        pred = predict(MODEL, x, expected_shape=y.shape)

        # Optimization loss in normalized space.
        loss = LOSS_FN(pred, y)
        loss.backward()
        OPT.step()

        run_loss += loss.item()
        run_rel += batch_metrics(pred.detach(), y)['rel_l2']
        nb += 1

        if CFG.get('log_every_batches') and b_idx % int(CFG['log_every_batches']) == 0:
            elapsed = time.time() - t_epoch
            print(f'  [epoch {epoch:03d}] batch {b_idx}/{len(TRAIN_LOADER)} loss={loss.item():.4e} elapsed={elapsed:.1f}s')

        if CFG.get('max_batches_per_epoch') is not None and b_idx >= int(CFG['max_batches_per_epoch']):
            print(f'  [epoch {epoch:03d}] early stop after {b_idx} batches (max_batches_per_epoch)')
            break

    SCH.step()
    train_lp = run_loss / max(nb, 1)
    train_rel = run_rel / max(nb, 1)

    if epoch % CFG['eval_every'] == 0:
        val_m = evaluate(MODEL, VAL_LOADER)
        test_m = evaluate(MODEL, TEST_LOADER) if HAS_TEST else None
        test_sr_m = evaluate(MODEL, TEST_SR_LOADER) if HAS_TEST_SR else None

        HIST['epoch'].append(epoch)
        HIST['train_lp'].append(train_lp)
        HIST['train_rel_l2'].append(train_rel)
        HIST['val_rel_l2'].append(val_m['rel_l2'])
        HIST['val_rmse'].append(val_m['rmse'])
        HIST['test_rel_l2'].append(test_m['rel_l2'] if test_m is not None else np.nan)
        HIST['test_rmse'].append(test_m['rmse'] if test_m is not None else np.nan)
        HIST['test_sr_rel_l2'].append(test_sr_m['rel_l2'] if test_sr_m is not None else np.nan)
        HIST['test_sr_rmse'].append(test_sr_m['rmse'] if test_sr_m is not None else np.nan)
        HIST['lr'].append(OPT.param_groups[0]['lr'])

        if val_m['rel_l2'] < best_val:
            best_val = val_m['rel_l2']
            torch.save(
                {
                    'model_state_dict': MODEL.state_dict(),
                    'config': dict(CFG),
                    'best_val_rel_l2': best_val,
                },
                CKPT_PATH,
            )

        epoch_time = time.time() - t_epoch
        msg = (
            f"[{epoch:03d}] train_lp(norm)={train_lp:.4e} "
            f"train_rel_l2(phys)={train_rel:.4e} "
            f"val_rel_l2(phys)={val_m['rel_l2']:.4e} val_rmse(phys)={val_m['rmse']:.4e} "
            f"lr={HIST['lr'][-1]:.2e} time={epoch_time:.1f}s"
        )
        if test_m is not None:
            msg += f" test_rel_l2(phys)={test_m['rel_l2']:.4e} test_rmse(phys)={test_m['rmse']:.4e}"
        if test_sr_m is not None:
            msg += f" test_sr_rel_l2(phys)={test_sr_m['rel_l2']:.4e} test_sr_rmse(phys)={test_sr_m['rmse']:.4e}"
        print(msg)

print(f"Best val rel-L2: {best_val:.4e}")
print(f"Checkpoint: {CKPT_PATH}")
# Out:
#   [epoch 001] batch 10/87 loss=5.9785e+00 elapsed=0.9s
#   [epoch 001] batch 20/87 loss=5.8165e+00 elapsed=1.3s
#   [epoch 001] batch 30/87 loss=5.3117e+00 elapsed=1.7s
#   [epoch 001] batch 40/87 loss=4.8866e+00 elapsed=2.1s
#   [epoch 001] batch 50/87 loss=4.2550e+00 elapsed=2.5s
#   [epoch 001] batch 60/87 loss=4.2267e+00 elapsed=2.9s
#   [epoch 001] batch 70/87 loss=3.6520e+00 elapsed=3.3s
#   [epoch 001] batch 80/87 loss=3.3835e+00 elapsed=3.8s
# [001] train_lp(norm)=4.7548e+00 train_rel_l2(phys)=7.6117e-01 val_rel_l2(phys)=1.0062e+00 val_rmse(phys)=3.3067e-01 lr=1.00e-03 time=5.4s test_rel_l2(phys)=1.0288e+00 test_rmse(phys)=1.0517e+00
#   [epoch 002] batch 10/87 loss=3.0770e+00 elapsed=0.4s
#   [epoch 002] batch 20/87 loss=2.8899e+00 elapsed=0.8s
#   [epoch 002] batch 30/87 loss=3.7110e+00 elapsed=1.2s
#   [epoch 002] batch 40/87 loss=2.7361e+00 elapsed=1.6s
#   [epoch 002] batch 50/87 loss=2.8168e+00 elapsed=2.0s
#   [epoch 002] batch 60/87 loss=2.8101e+00 elapsed=2.5s
#   [epoch 002] batch 70/87 loss=2.4576e+00 elapsed=2.9s
#   [epoch 002] batch 80/87 loss=2.4875e+00 elapsed=3.3s
# [002] train_lp(norm)=2.8750e+00 train_rel_l2(phys)=4.4885e-01 val_rel_l2(phys)=1.0084e+00 val_rmse(phys)=3.3125e-01 lr=9.99e-04 time=4.9s test_rel_l2(phys)=1.0416e+00 test_rmse(phys)=1.0410e+00
#   [epoch 003] batch 10/87 loss=2.3955e+00 elapsed=0.4s
#   [epoch 003] batch 20/87 loss=2.1718e+00 elapsed=0.8s
#   [epoch 003] batch 30/87 loss=2.2294e+00 elapsed=1.2s
#   [epoch 003] batch 40/87 loss=2.0224e+00 elapsed=1.7s
#   [epoch 003] batch 50/87 loss=2.1789e+00 elapsed=2.1s
#   [epoch 003] batch 60/87 loss=1.9317e+00 elapsed=2.5s
#   [epoch 003] batch 70/87 loss=2.2717e+00 elapsed=2.9s
#   [epoch 003] batch 80/87 loss=2.0777e+00 elapsed=3.3s
# [003] train_lp(norm)=2.2302e+00 train_rel_l2(phys)=3.4460e-01 val_rel_l2(phys)=1.0111e+00 val_rmse(phys)=3.3191e-01 lr=9.98e-04 time=4.9s test_rel_l2(phys)=1.0596e+00 test_rmse(phys)=1.0403e+00
#   [epoch 004] batch 10/87 loss=1.9326e+00 elapsed=0.4s
#   [epoch 004] batch 20/87 loss=1.6841e+00 elapsed=0.8s
#   [epoch 004] batch 30/87 loss=1.8868e+00 elapsed=1.2s
#   [epoch 004] batch 40/87 loss=1.9439e+00 elapsed=1.6s
#   [epoch 004] batch 50/87 loss=1.9654e+00 elapsed=2.0s
#   [epoch 004] batch 60/87 loss=1.8284e+00 elapsed=2.4s
#   [epoch 004] batch 70/87 loss=1.7547e+00 elapsed=2.9s
#   [epoch 004] batch 80/87 loss=1.6478e+00 elapsed=3.3s
# [004] train_lp(norm)=1.8952e+00 train_rel_l2(phys)=2.9258e-01 val_rel_l2(phys)=1.0070e+00 val_rmse(phys)=3.3086e-01 lr=9.97e-04 time=4.8s test_rel_l2(phys)=1.0486e+00 test_rmse(phys)=1.0377e+00
#   [epoch 005] batch 10/87 loss=1.5315e+00 elapsed=0.4s
#   [epoch 005] batch 20/87 loss=1.6722e+00 elapsed=0.8s
#   [epoch 005] batch 30/87 loss=1.6123e+00 elapsed=1.2s
#   [epoch 005] batch 40/87 loss=1.5976e+00 elapsed=1.6s
#   [epoch 005] batch 50/87 loss=1.6468e+00 elapsed=2.0s
#   [epoch 005] batch 60/87 loss=1.8131e+00 elapsed=2.4s
#   [epoch 005] batch 70/87 loss=1.5308e+00 elapsed=2.8s
#   [epoch 005] batch 80/87 loss=1.6159e+00 elapsed=3.2s
# [005] train_lp(norm)=1.6808e+00 train_rel_l2(phys)=2.5890e-01 val_rel_l2(phys)=1.0078e+00 val_rmse(phys)=3.3106e-01 lr=9.96e-04 time=4.8s test_rel_l2(phys)=1.0585e+00 test_rmse(phys)=1.0388e+00
#   [epoch 006] batch 10/87 loss=1.5536e+00 elapsed=0.4s
#   [epoch 006] batch 20/87 loss=1.5010e+00 elapsed=0.8s
#   [epoch 006] batch 30/87 loss=1.4965e+00 elapsed=1.2s
#   [epoch 006] batch 40/87 loss=1.5337e+00 elapsed=1.6s
#   [epoch 006] batch 50/87 loss=1.5263e+00 elapsed=2.0s
#   [epoch 006] batch 60/87 loss=1.4389e+00 elapsed=2.4s
#   [epoch 006] batch 70/87 loss=1.4785e+00 elapsed=2.8s
#   [epoch 006] batch 80/87 loss=1.3664e+00 elapsed=3.2s
# [006] train_lp(norm)=1.4957e+00 train_rel_l2(phys)=2.3113e-01 val_rel_l2(phys)=1.0083e+00 val_rmse(phys)=3.3117e-01 lr=9.94e-04 time=4.8s test_rel_l2(phys)=1.0700e+00 test_rmse(phys)=1.0407e+00
#   [epoch 007] batch 10/87 loss=1.3107e+00 elapsed=0.4s
#   [epoch 007] batch 20/87 loss=1.2867e+00 elapsed=0.8s
#   [epoch 007] batch 30/87 loss=1.3497e+00 elapsed=1.2s
#   [epoch 007] batch 40/87 loss=1.5594e+00 elapsed=1.6s
#   [epoch 007] batch 50/87 loss=1.7277e+00 elapsed=2.0s
#   [epoch 007] batch 60/87 loss=1.7192e+00 elapsed=2.4s
#   [epoch 007] batch 70/87 loss=1.3096e+00 elapsed=2.8s
#   [epoch 007] batch 80/87 loss=1.2812e+00 elapsed=3.2s
# [007] train_lp(norm)=1.3739e+00 train_rel_l2(phys)=2.1226e-01 val_rel_l2(phys)=1.0065e+00 val_rmse(phys)=3.3069e-01 lr=9.92e-04 time=4.8s test_rel_l2(phys)=1.0590e+00 test_rmse(phys)=1.0385e+00
#   [epoch 008] batch 10/87 loss=1.2598e+00 elapsed=0.4s
#   [epoch 008] batch 20/87 loss=1.3671e+00 elapsed=0.8s
#   [epoch 008] batch 30/87 loss=1.3058e+00 elapsed=1.2s
#   [epoch 008] batch 40/87 loss=1.3345e+00 elapsed=1.6s
#   [epoch 008] batch 50/87 loss=1.2907e+00 elapsed=2.0s
#   [epoch 008] batch 60/87 loss=1.1947e+00 elapsed=2.4s
#   [epoch 008] batch 70/87 loss=1.1229e+00 elapsed=2.8s
#   [epoch 008] batch 80/87 loss=1.2291e+00 elapsed=3.2s
# [008] train_lp(norm)=1.2667e+00 train_rel_l2(phys)=1.9715e-01 val_rel_l2(phys)=1.0061e+00 val_rmse(phys)=3.3057e-01 lr=9.89e-04 time=4.8s test_rel_l2(phys)=1.0636e+00 test_rmse(phys)=1.0387e+00
#   [epoch 009] batch 10/87 loss=1.1054e+00 elapsed=0.4s
#   [epoch 009] batch 20/87 loss=1.2744e+00 elapsed=0.8s
#   [epoch 009] batch 30/87 loss=1.2391e+00 elapsed=1.2s
#   [epoch 009] batch 40/87 loss=1.3530e+00 elapsed=1.6s
#   [epoch 009] batch 50/87 loss=1.2754e+00 elapsed=2.0s
#   [epoch 009] batch 60/87 loss=1.0536e+00 elapsed=2.4s
#   [epoch 009] batch 70/87 loss=1.1664e+00 elapsed=2.8s
#   [epoch 009] batch 80/87 loss=1.4061e+00 elapsed=3.2s
# [009] train_lp(norm)=1.2263e+00 train_rel_l2(phys)=1.8884e-01 val_rel_l2(phys)=1.0047e+00 val_rmse(phys)=3.3017e-01 lr=9.86e-04 time=4.8s test_rel_l2(phys)=1.0518e+00 test_rmse(phys)=1.0370e+00
#   [epoch 010] batch 10/87 loss=1.2025e+00 elapsed=0.4s
#   [epoch 010] batch 20/87 loss=1.1414e+00 elapsed=0.8s
#   [epoch 010] batch 30/87 loss=1.1590e+00 elapsed=1.2s
#   [epoch 010] batch 40/87 loss=1.0815e+00 elapsed=1.6s
#   [epoch 010] batch 50/87 loss=1.2761e+00 elapsed=2.0s
#   [epoch 010] batch 60/87 loss=1.0529e+00 elapsed=2.4s
#   [epoch 010] batch 70/87 loss=1.1101e+00 elapsed=2.8s
#   [epoch 010] batch 80/87 loss=1.1308e+00 elapsed=3.2s
# [010] train_lp(norm)=1.1350e+00 train_rel_l2(phys)=1.7547e-01 val_rel_l2(phys)=1.0076e+00 val_rmse(phys)=3.3094e-01 lr=9.83e-04 time=4.7s test_rel_l2(phys)=1.0781e+00 test_rmse(phys)=1.0391e+00
#   [epoch 011] batch 10/87 loss=1.1041e+00 elapsed=0.4s
#   [epoch 011] batch 20/87 loss=1.0904e+00 elapsed=0.8s
#   [epoch 011] batch 30/87 loss=1.0212e+00 elapsed=1.2s
#   [epoch 011] batch 40/87 loss=1.0037e+00 elapsed=1.6s
#   [epoch 011] batch 50/87 loss=1.2583e+00 elapsed=2.0s
#   [epoch 011] batch 60/87 loss=1.0691e+00 elapsed=2.4s
#   [epoch 011] batch 70/87 loss=1.0579e+00 elapsed=2.8s
#   [epoch 011] batch 80/87 loss=1.0354e+00 elapsed=3.2s
# [011] train_lp(norm)=1.0528e+00 train_rel_l2(phys)=1.6389e-01 val_rel_l2(phys)=1.0037e+00 val_rmse(phys)=3.2990e-01 lr=9.79e-04 time=4.8s test_rel_l2(phys)=1.0537e+00 test_rmse(phys)=1.0372e+00
#   [epoch 012] batch 10/87 loss=1.1106e+00 elapsed=0.4s
#   [epoch 012] batch 20/87 loss=1.0306e+00 elapsed=0.8s
#   [epoch 012] batch 30/87 loss=9.8214e-01 elapsed=1.2s
#   [epoch 012] batch 40/87 loss=9.6438e-01 elapsed=1.6s
#   [epoch 012] batch 50/87 loss=1.0638e+00 elapsed=2.0s
#   [epoch 012] batch 60/87 loss=1.0339e+00 elapsed=2.4s
#   [epoch 012] batch 70/87 loss=1.0300e+00 elapsed=2.8s
#   [epoch 012] batch 80/87 loss=9.7003e-01 elapsed=3.2s
# [012] train_lp(norm)=1.0573e+00 train_rel_l2(phys)=1.6431e-01 val_rel_l2(phys)=1.0045e+00 val_rmse(phys)=3.3010e-01 lr=9.76e-04 time=4.8s test_rel_l2(phys)=1.0553e+00 test_rmse(phys)=1.0374e+00
#   [epoch 013] batch 10/87 loss=1.0338e+00 elapsed=0.4s
#   [epoch 013] batch 20/87 loss=9.5113e-01 elapsed=0.8s
#   [epoch 013] batch 30/87 loss=1.0353e+00 elapsed=1.2s
#   [epoch 013] batch 40/87 loss=9.2561e-01 elapsed=1.6s
#   [epoch 013] batch 50/87 loss=9.0768e-01 elapsed=2.0s
#   [epoch 013] batch 60/87 loss=8.8219e-01 elapsed=2.4s
#   [epoch 013] batch 70/87 loss=1.0512e+00 elapsed=2.8s
#   [epoch 013] batch 80/87 loss=9.9335e-01 elapsed=3.2s
# [013] train_lp(norm)=9.8197e-01 train_rel_l2(phys)=1.5315e-01 val_rel_l2(phys)=1.0035e+00 val_rmse(phys)=3.2981e-01 lr=9.71e-04 time=4.8s test_rel_l2(phys)=1.0577e+00 test_rmse(phys)=1.0369e+00
#   [epoch 014] batch 10/87 loss=8.9545e-01 elapsed=0.4s
#   [epoch 014] batch 20/87 loss=1.0355e+00 elapsed=0.8s
#   [epoch 014] batch 30/87 loss=1.0246e+00 elapsed=1.2s
#   [epoch 014] batch 40/87 loss=1.0286e+00 elapsed=1.6s
#   [epoch 014] batch 50/87 loss=9.1707e-01 elapsed=2.0s
#   [epoch 014] batch 60/87 loss=9.5046e-01 elapsed=2.4s
#   [epoch 014] batch 70/87 loss=9.2980e-01 elapsed=2.8s
#   [epoch 014] batch 80/87 loss=9.2058e-01 elapsed=3.2s
# [014] train_lp(norm)=9.8115e-01 train_rel_l2(phys)=1.5304e-01 val_rel_l2(phys)=1.0024e+00 val_rmse(phys)=3.2953e-01 lr=9.67e-04 time=4.8s test_rel_l2(phys)=1.0489e+00 test_rmse(phys)=1.0369e+00
#   [epoch 015] batch 10/87 loss=1.0142e+00 elapsed=0.4s
#   [epoch 015] batch 20/87 loss=1.0119e+00 elapsed=0.8s
#   [epoch 015] batch 30/87 loss=1.0065e+00 elapsed=1.2s
#   [epoch 015] batch 40/87 loss=8.8028e-01 elapsed=1.6s
#   [epoch 015] batch 50/87 loss=9.1858e-01 elapsed=2.0s
#   [epoch 015] batch 60/87 loss=8.5120e-01 elapsed=2.4s
#   [epoch 015] batch 70/87 loss=8.4628e-01 elapsed=2.8s
#   [epoch 015] batch 80/87 loss=8.2959e-01 elapsed=3.2s
# [015] train_lp(norm)=9.3128e-01 train_rel_l2(phys)=1.4475e-01 val_rel_l2(phys)=1.0052e+00 val_rmse(phys)=3.3028e-01 lr=9.62e-04 time=4.8s test_rel_l2(phys)=1.0723e+00 test_rmse(phys)=1.0379e+00
#   [epoch 016] batch 10/87 loss=9.6982e-01 elapsed=0.4s
#   [epoch 016] batch 20/87 loss=9.6846e-01 elapsed=0.8s
#   [epoch 016] batch 30/87 loss=8.6418e-01 elapsed=1.2s
#   [epoch 016] batch 40/87 loss=9.0823e-01 elapsed=1.6s
#   [epoch 016] batch 50/87 loss=9.0135e-01 elapsed=2.0s
#   [epoch 016] batch 60/87 loss=8.0604e-01 elapsed=2.4s
#   [epoch 016] batch 70/87 loss=8.8603e-01 elapsed=2.8s
#   [epoch 016] batch 80/87 loss=8.7848e-01 elapsed=3.2s
# [016] train_lp(norm)=9.1453e-01 train_rel_l2(phys)=1.4207e-01 val_rel_l2(phys)=1.0039e+00 val_rmse(phys)=3.2992e-01 lr=9.57e-04 time=4.8s test_rel_l2(phys)=1.0541e+00 test_rmse(phys)=1.0366e+00
#   [epoch 017] batch 10/87 loss=1.0203e+00 elapsed=0.4s
#   [epoch 017] batch 20/87 loss=9.0842e-01 elapsed=0.8s
#   [epoch 017] batch 30/87 loss=9.3976e-01 elapsed=1.2s
#   [epoch 017] batch 40/87 loss=8.8980e-01 elapsed=1.6s
#   [epoch 017] batch 50/87 loss=8.2812e-01 elapsed=2.0s
#   [epoch 017] batch 60/87 loss=8.9750e-01 elapsed=2.4s
#   [epoch 017] batch 70/87 loss=8.2013e-01 elapsed=2.8s
#   [epoch 017] batch 80/87 loss=7.3061e-01 elapsed=3.2s
# [017] train_lp(norm)=9.0255e-01 train_rel_l2(phys)=1.4093e-01 val_rel_l2(phys)=1.0035e+00 val_rmse(phys)=3.2985e-01 lr=9.51e-04 time=4.8s test_rel_l2(phys)=1.0557e+00 test_rmse(phys)=1.0368e+00
#   [epoch 018] batch 10/87 loss=8.2079e-01 elapsed=0.4s
#   [epoch 018] batch 20/87 loss=9.1985e-01 elapsed=0.8s
#   [epoch 018] batch 30/87 loss=8.4255e-01 elapsed=1.2s
#   [epoch 018] batch 40/87 loss=8.7314e-01 elapsed=1.6s
#   [epoch 018] batch 50/87 loss=8.3458e-01 elapsed=2.0s
#   [epoch 018] batch 60/87 loss=9.5253e-01 elapsed=2.4s
#   [epoch 018] batch 70/87 loss=7.8996e-01 elapsed=2.8s
#   [epoch 018] batch 80/87 loss=7.6419e-01 elapsed=3.2s
# [018] train_lp(norm)=8.2472e-01 train_rel_l2(phys)=1.2872e-01 val_rel_l2(phys)=1.0034e+00 val_rmse(phys)=3.2979e-01 lr=9.46e-04 time=4.8s test_rel_l2(phys)=1.0581e+00 test_rmse(phys)=1.0366e+00
#   [epoch 019] batch 10/87 loss=9.9303e-01 elapsed=0.4s
#   [epoch 019] batch 20/87 loss=9.2525e-01 elapsed=0.8s
#   [epoch 019] batch 30/87 loss=8.4128e-01 elapsed=1.2s
#   [epoch 019] batch 40/87 loss=8.6531e-01 elapsed=1.6s
#   [epoch 019] batch 50/87 loss=7.6865e-01 elapsed=2.0s
#   [epoch 019] batch 60/87 loss=7.5139e-01 elapsed=2.4s
#   [epoch 019] batch 70/87 loss=7.9020e-01 elapsed=2.8s
#   [epoch 019] batch 80/87 loss=8.9535e-01 elapsed=3.2s
# [019] train_lp(norm)=8.5651e-01 train_rel_l2(phys)=1.3296e-01 val_rel_l2(phys)=1.0041e+00 val_rmse(phys)=3.2999e-01 lr=9.39e-04 time=4.8s test_rel_l2(phys)=1.0666e+00 test_rmse(phys)=1.0375e+00
#   [epoch 020] batch 10/87 loss=8.9509e-01 elapsed=0.4s
#   [epoch 020] batch 20/87 loss=8.6603e-01 elapsed=0.8s
#   [epoch 020] batch 30/87 loss=6.8914e-01 elapsed=1.2s
#   [epoch 020] batch 40/87 loss=1.0106e+00 elapsed=1.6s
#   [epoch 020] batch 50/87 loss=6.9070e-01 elapsed=2.1s
#   [epoch 020] batch 60/87 loss=8.1081e-01 elapsed=2.5s
#   [epoch 020] batch 70/87 loss=7.9702e-01 elapsed=3.0s
#   [epoch 020] batch 80/87 loss=7.3836e-01 elapsed=3.4s
# [020] train_lp(norm)=7.9750e-01 train_rel_l2(phys)=1.2463e-01 val_rel_l2(phys)=1.0031e+00 val_rmse(phys)=3.2970e-01 lr=9.33e-04 time=5.0s test_rel_l2(phys)=1.0561e+00 test_rmse(phys)=1.0365e+00
#   [epoch 021] batch 10/87 loss=7.4715e-01 elapsed=0.4s
#   [epoch 021] batch 20/87 loss=7.4372e-01 elapsed=0.8s
#   [epoch 021] batch 30/87 loss=7.8811e-01 elapsed=1.2s
#   [epoch 021] batch 40/87 loss=7.1458e-01 elapsed=1.6s
#   [epoch 021] batch 50/87 loss=7.2127e-01 elapsed=2.1s
#   [epoch 021] batch 60/87 loss=8.3634e-01 elapsed=2.5s
#   [epoch 021] batch 70/87 loss=7.0265e-01 elapsed=2.9s
#   [epoch 021] batch 80/87 loss=6.8244e-01 elapsed=3.3s
# [021] train_lp(norm)=7.5153e-01 train_rel_l2(phys)=1.1803e-01 val_rel_l2(phys)=1.0035e+00 val_rmse(phys)=3.2981e-01 lr=9.26e-04 time=4.9s test_rel_l2(phys)=1.0677e+00 test_rmse(phys)=1.0371e+00
#   [epoch 022] batch 10/87 loss=6.9248e-01 elapsed=0.4s
#   [epoch 022] batch 20/87 loss=8.0452e-01 elapsed=0.8s
#   [epoch 022] batch 30/87 loss=7.8904e-01 elapsed=1.2s
#   [epoch 022] batch 40/87 loss=6.8095e-01 elapsed=1.6s
#   [epoch 022] batch 50/87 loss=7.2402e-01 elapsed=2.0s
#   [epoch 022] batch 60/87 loss=8.0668e-01 elapsed=2.5s
#   [epoch 022] batch 70/87 loss=1.0839e+00 elapsed=2.9s
#   [epoch 022] batch 80/87 loss=1.0648e+00 elapsed=3.3s
# [022] train_lp(norm)=8.0231e-01 train_rel_l2(phys)=1.2625e-01 val_rel_l2(phys)=1.0032e+00 val_rmse(phys)=3.2973e-01 lr=9.19e-04 time=5.0s test_rel_l2(phys)=1.0495e+00 test_rmse(phys)=1.0358e+00
#   [epoch 023] batch 10/87 loss=7.5622e-01 elapsed=0.4s
#   [epoch 023] batch 20/87 loss=7.5909e-01 elapsed=0.8s
#   [epoch 023] batch 30/87 loss=8.2830e-01 elapsed=1.2s
#   [epoch 023] batch 40/87 loss=6.9329e-01 elapsed=1.6s
#   [epoch 023] batch 50/87 loss=6.4791e-01 elapsed=2.1s
#   [epoch 023] batch 60/87 loss=7.0822e-01 elapsed=2.5s
#   [epoch 023] batch 70/87 loss=7.3126e-01 elapsed=2.9s
#   [epoch 023] batch 80/87 loss=6.8585e-01 elapsed=3.3s
# [023] train_lp(norm)=7.4986e-01 train_rel_l2(phys)=1.1801e-01 val_rel_l2(phys)=1.0039e+00 val_rmse(phys)=3.2991e-01 lr=9.12e-04 time=4.9s test_rel_l2(phys)=1.0530e+00 test_rmse(phys)=1.0364e+00
#   [epoch 024] batch 10/87 loss=7.8769e-01 elapsed=0.4s
#   [epoch 024] batch 20/87 loss=7.4501e-01 elapsed=0.8s
#   [epoch 024] batch 30/87 loss=6.5951e-01 elapsed=1.2s
#   [epoch 024] batch 40/87 loss=6.8507e-01 elapsed=1.6s
#   [epoch 024] batch 50/87 loss=8.5203e-01 elapsed=2.1s
#   [epoch 024] batch 60/87 loss=7.0959e-01 elapsed=2.5s
#   [epoch 024] batch 70/87 loss=6.2183e-01 elapsed=2.9s
#   [epoch 024] batch 80/87 loss=6.3889e-01 elapsed=3.3s
# [024] train_lp(norm)=7.2878e-01 train_rel_l2(phys)=1.1381e-01 val_rel_l2(phys)=1.0034e+00 val_rmse(phys)=3.2979e-01 lr=9.05e-04 time=4.9s test_rel_l2(phys)=1.0565e+00 test_rmse(phys)=1.0365e+00
#   [epoch 025] batch 10/87 loss=6.8670e-01 elapsed=0.4s
#   [epoch 025] batch 20/87 loss=6.7172e-01 elapsed=0.8s
#   [epoch 025] batch 30/87 loss=6.7887e-01 elapsed=1.2s
#   [epoch 025] batch 40/87 loss=6.8477e-01 elapsed=1.6s
#   [epoch 025] batch 50/87 loss=8.0120e-01 elapsed=2.1s
#   [epoch 025] batch 60/87 loss=6.8873e-01 elapsed=2.5s
#   [epoch 025] batch 70/87 loss=6.1289e-01 elapsed=2.9s
#   [epoch 025] batch 80/87 loss=6.5835e-01 elapsed=3.3s
# [025] train_lp(norm)=6.9421e-01 train_rel_l2(phys)=1.0863e-01 val_rel_l2(phys)=1.0032e+00 val_rmse(phys)=3.2975e-01 lr=8.97e-04 time=4.9s test_rel_l2(phys)=1.0552e+00 test_rmse(phys)=1.0365e+00
#   [epoch 026] batch 10/87 loss=6.5856e-01 elapsed=0.4s
#   [epoch 026] batch 20/87 loss=6.2140e-01 elapsed=0.8s
#   [epoch 026] batch 30/87 loss=6.3298e-01 elapsed=1.3s
#   [epoch 026] batch 40/87 loss=6.0278e-01 elapsed=1.7s
#   [epoch 026] batch 50/87 loss=6.4983e-01 elapsed=2.1s
#   [epoch 026] batch 60/87 loss=6.5988e-01 elapsed=2.5s
#   [epoch 026] batch 70/87 loss=7.5884e-01 elapsed=2.9s
#   [epoch 026] batch 80/87 loss=7.9982e-01 elapsed=3.3s
# [026] train_lp(norm)=6.8396e-01 train_rel_l2(phys)=1.0678e-01 val_rel_l2(phys)=1.0036e+00 val_rmse(phys)=3.2982e-01 lr=8.89e-04 time=4.9s test_rel_l2(phys)=1.0610e+00 test_rmse(phys)=1.0368e+00
#   [epoch 027] batch 10/87 loss=7.1446e-01 elapsed=0.4s
#   [epoch 027] batch 20/87 loss=7.0723e-01 elapsed=0.8s
#   [epoch 027] batch 30/87 loss=7.1271e-01 elapsed=1.2s
#   [epoch 027] batch 40/87 loss=6.5575e-01 elapsed=1.6s
#   [epoch 027] batch 50/87 loss=8.6000e-01 elapsed=2.0s
#   [epoch 027] batch 60/87 loss=5.7652e-01 elapsed=2.5s
#   [epoch 027] batch 70/87 loss=5.6774e-01 elapsed=2.9s
#   [epoch 027] batch 80/87 loss=6.6105e-01 elapsed=3.3s
# [027] train_lp(norm)=6.9696e-01 train_rel_l2(phys)=1.0843e-01 val_rel_l2(phys)=1.0028e+00 val_rmse(phys)=3.2960e-01 lr=8.80e-04 time=4.9s test_rel_l2(phys)=1.0576e+00 test_rmse(phys)=1.0365e+00
#   [epoch 028] batch 10/87 loss=6.1945e-01 elapsed=0.4s
#   [epoch 028] batch 20/87 loss=6.1943e-01 elapsed=0.8s
#   [epoch 028] batch 30/87 loss=7.7332e-01 elapsed=1.2s
#   [epoch 028] batch 40/87 loss=6.2466e-01 elapsed=1.6s
#   [epoch 028] batch 50/87 loss=6.8197e-01 elapsed=2.1s
#   [epoch 028] batch 60/87 loss=6.9432e-01 elapsed=2.5s
#   [epoch 028] batch 70/87 loss=6.8599e-01 elapsed=2.9s
#   [epoch 028] batch 80/87 loss=6.3503e-01 elapsed=3.3s
# [028] train_lp(norm)=6.9062e-01 train_rel_l2(phys)=1.0789e-01 val_rel_l2(phys)=1.0023e+00 val_rmse(phys)=3.2947e-01 lr=8.72e-04 time=5.0s test_rel_l2(phys)=1.0540e+00 test_rmse(phys)=1.0358e+00
#   [epoch 029] batch 10/87 loss=8.0575e-01 elapsed=0.4s
#   [epoch 029] batch 20/87 loss=7.2229e-01 elapsed=0.8s
#   [epoch 029] batch 30/87 loss=6.0959e-01 elapsed=1.3s
#   [epoch 029] batch 40/87 loss=7.4100e-01 elapsed=1.7s
#   [epoch 029] batch 50/87 loss=6.3768e-01 elapsed=2.1s
#   [epoch 029] batch 60/87 loss=6.8852e-01 elapsed=2.5s
#   [epoch 029] batch 70/87 loss=6.8169e-01 elapsed=2.9s
#   [epoch 029] batch 80/87 loss=6.5516e-01 elapsed=3.3s
# [029] train_lp(norm)=6.7521e-01 train_rel_l2(phys)=1.0535e-01 val_rel_l2(phys)=1.0024e+00 val_rmse(phys)=3.2949e-01 lr=8.63e-04 time=4.9s test_rel_l2(phys)=1.0498e+00 test_rmse(phys)=1.0357e+00
#   [epoch 030] batch 10/87 loss=5.6507e-01 elapsed=0.4s
#   [epoch 030] batch 20/87 loss=6.6598e-01 elapsed=0.8s
#   [epoch 030] batch 30/87 loss=5.7845e-01 elapsed=1.3s
#   [epoch 030] batch 40/87 loss=6.2888e-01 elapsed=1.7s
#   [epoch 030] batch 50/87 loss=6.5069e-01 elapsed=2.1s
#   [epoch 030] batch 60/87 loss=6.8401e-01 elapsed=2.5s
#   [epoch 030] batch 70/87 loss=6.5089e-01 elapsed=3.0s
#   [epoch 030] batch 80/87 loss=6.8487e-01 elapsed=3.4s
# [030] train_lp(norm)=6.5433e-01 train_rel_l2(phys)=1.0195e-01 val_rel_l2(phys)=1.0030e+00 val_rmse(phys)=3.2968e-01 lr=8.54e-04 time=5.0s test_rel_l2(phys)=1.0414e+00 test_rmse(phys)=1.0352e+00
#   [epoch 031] batch 10/87 loss=6.3950e-01 elapsed=0.4s
#   [epoch 031] batch 20/87 loss=6.8161e-01 elapsed=0.9s
#   [epoch 031] batch 30/87 loss=7.8110e-01 elapsed=1.3s
#   [epoch 031] batch 40/87 loss=6.4429e-01 elapsed=1.8s
#   [epoch 031] batch 50/87 loss=5.8828e-01 elapsed=2.2s
#   [epoch 031] batch 60/87 loss=6.6865e-01 elapsed=2.6s
#   [epoch 031] batch 70/87 loss=5.9134e-01 elapsed=3.0s
#   [epoch 031] batch 80/87 loss=6.0410e-01 elapsed=3.4s
# [031] train_lp(norm)=6.2570e-01 train_rel_l2(phys)=9.8003e-02 val_rel_l2(phys)=1.0028e+00 val_rmse(phys)=3.2960e-01 lr=8.44e-04 time=5.0s test_rel_l2(phys)=1.0537e+00 test_rmse(phys)=1.0361e+00
#   [epoch 032] batch 10/87 loss=6.3783e-01 elapsed=0.4s
#   [epoch 032] batch 20/87 loss=5.4392e-01 elapsed=0.8s
#   [epoch 032] batch 30/87 loss=5.7729e-01 elapsed=1.2s
#   [epoch 032] batch 40/87 loss=6.6764e-01 elapsed=1.7s
#   [epoch 032] batch 50/87 loss=6.4070e-01 elapsed=2.1s
#   [epoch 032] batch 60/87 loss=5.3268e-01 elapsed=2.5s
#   [epoch 032] batch 70/87 loss=5.5636e-01 elapsed=2.9s
#   [epoch 032] batch 80/87 loss=5.5098e-01 elapsed=3.3s
# [032] train_lp(norm)=6.0696e-01 train_rel_l2(phys)=9.5043e-02 val_rel_l2(phys)=1.0028e+00 val_rmse(phys)=3.2961e-01 lr=8.35e-04 time=4.8s test_rel_l2(phys)=1.0553e+00 test_rmse(phys)=1.0360e+00
#   [epoch 033] batch 10/87 loss=5.6469e-01 elapsed=0.4s
#   [epoch 033] batch 20/87 loss=6.0609e-01 elapsed=0.8s
#   [epoch 033] batch 30/87 loss=6.2580e-01 elapsed=1.2s
#   [epoch 033] batch 40/87 loss=6.4446e-01 elapsed=1.6s
#   [epoch 033] batch 50/87 loss=5.8404e-01 elapsed=2.1s
#   [epoch 033] batch 60/87 loss=5.5450e-01 elapsed=2.5s
#   [epoch 033] batch 70/87 loss=5.3470e-01 elapsed=2.9s
#   [epoch 033] batch 80/87 loss=6.2876e-01 elapsed=3.3s
# [033] train_lp(norm)=5.7448e-01 train_rel_l2(phys)=8.9691e-02 val_rel_l2(phys)=1.0026e+00 val_rmse(phys)=3.2957e-01 lr=8.25e-04 time=4.9s test_rel_l2(phys)=1.0553e+00 test_rmse(phys)=1.0361e+00
#   [epoch 034] batch 10/87 loss=6.2862e-01 elapsed=0.4s
#   [epoch 034] batch 20/87 loss=5.5523e-01 elapsed=0.8s
#   [epoch 034] batch 30/87 loss=5.3850e-01 elapsed=1.3s
#   [epoch 034] batch 40/87 loss=6.1697e-01 elapsed=1.7s
#   [epoch 034] batch 50/87 loss=5.6777e-01 elapsed=2.1s
#   [epoch 034] batch 60/87 loss=5.8375e-01 elapsed=2.5s
#   [epoch 034] batch 70/87 loss=5.1657e-01 elapsed=2.9s
#   [epoch 034] batch 80/87 loss=6.0176e-01 elapsed=3.4s
# [034] train_lp(norm)=5.8993e-01 train_rel_l2(phys)=9.1977e-02 val_rel_l2(phys)=1.0032e+00 val_rmse(phys)=3.2973e-01 lr=8.15e-04 time=5.0s test_rel_l2(phys)=1.0620e+00 test_rmse(phys)=1.0364e+00
#   [epoch 035] batch 10/87 loss=7.0345e-01 elapsed=0.4s
#   [epoch 035] batch 20/87 loss=6.3403e-01 elapsed=0.8s
#   [epoch 035] batch 30/87 loss=5.7344e-01 elapsed=1.2s
#   [epoch 035] batch 40/87 loss=5.8546e-01 elapsed=1.6s
#   [epoch 035] batch 50/87 loss=5.1526e-01 elapsed=2.1s
#   [epoch 035] batch 60/87 loss=5.4571e-01 elapsed=2.5s
#   [epoch 035] batch 70/87 loss=5.2711e-01 elapsed=2.9s
#   [epoch 035] batch 80/87 loss=4.9898e-01 elapsed=3.3s
# [035] train_lp(norm)=5.8645e-01 train_rel_l2(phys)=9.1460e-02 val_rel_l2(phys)=1.0027e+00 val_rmse(phys)=3.2958e-01 lr=8.04e-04 time=4.9s test_rel_l2(phys)=1.0601e+00 test_rmse(phys)=1.0360e+00
#   [epoch 036] batch 10/87 loss=6.4671e-01 elapsed=0.4s
#   [epoch 036] batch 20/87 loss=5.3260e-01 elapsed=0.8s
#   [epoch 036] batch 30/87 loss=5.6320e-01 elapsed=1.2s
#   [epoch 036] batch 40/87 loss=5.6922e-01 elapsed=1.6s
#   [epoch 036] batch 50/87 loss=5.3854e-01 elapsed=2.0s
#   [epoch 036] batch 60/87 loss=5.9612e-01 elapsed=2.5s
#   [epoch 036] batch 70/87 loss=4.8024e-01 elapsed=2.9s
#   [epoch 036] batch 80/87 loss=5.3177e-01 elapsed=3.3s
# [036] train_lp(norm)=5.4536e-01 train_rel_l2(phys)=8.5344e-02 val_rel_l2(phys)=1.0030e+00 val_rmse(phys)=3.2967e-01 lr=7.94e-04 time=4.9s test_rel_l2(phys)=1.0621e+00 test_rmse(phys)=1.0362e+00
#   [epoch 037] batch 10/87 loss=5.4766e-01 elapsed=0.4s
#   [epoch 037] batch 20/87 loss=5.7435e-01 elapsed=0.8s
#   [epoch 037] batch 30/87 loss=5.9544e-01 elapsed=1.2s
#   [epoch 037] batch 40/87 loss=6.4610e-01 elapsed=1.6s
#   [epoch 037] batch 50/87 loss=5.4866e-01 elapsed=2.1s
#   [epoch 037] batch 60/87 loss=5.3389e-01 elapsed=2.5s
#   [epoch 037] batch 70/87 loss=5.8017e-01 elapsed=2.9s
#   [epoch 037] batch 80/87 loss=5.2216e-01 elapsed=3.4s
# [037] train_lp(norm)=5.6550e-01 train_rel_l2(phys)=8.8686e-02 val_rel_l2(phys)=1.0020e+00 val_rmse(phys)=3.2941e-01 lr=7.83e-04 time=5.1s test_rel_l2(phys)=1.0507e+00 test_rmse(phys)=1.0354e+00
#   [epoch 038] batch 10/87 loss=6.3233e-01 elapsed=0.4s
#   [epoch 038] batch 20/87 loss=6.1931e-01 elapsed=0.8s
#   [epoch 038] batch 30/87 loss=5.7807e-01 elapsed=1.2s
#   [epoch 038] batch 40/87 loss=4.8294e-01 elapsed=1.6s
#   [epoch 038] batch 50/87 loss=5.9055e-01 elapsed=2.0s
#   [epoch 038] batch 60/87 loss=5.5486e-01 elapsed=2.5s
#   [epoch 038] batch 70/87 loss=5.2650e-01 elapsed=2.9s
#   [epoch 038] batch 80/87 loss=4.7633e-01 elapsed=3.3s
# [038] train_lp(norm)=5.5909e-01 train_rel_l2(phys)=8.7656e-02 val_rel_l2(phys)=1.0021e+00 val_rmse(phys)=3.2944e-01 lr=7.72e-04 time=4.9s test_rel_l2(phys)=1.0556e+00 test_rmse(phys)=1.0359e+00
#   [epoch 039] batch 10/87 loss=6.7379e-01 elapsed=0.4s
#   [epoch 039] batch 20/87 loss=5.2836e-01 elapsed=0.8s
#   [epoch 039] batch 30/87 loss=5.3818e-01 elapsed=1.2s
#   [epoch 039] batch 40/87 loss=5.2584e-01 elapsed=1.6s
#   [epoch 039] batch 50/87 loss=5.2427e-01 elapsed=2.0s
#   [epoch 039] batch 60/87 loss=5.3368e-01 elapsed=2.4s
#   [epoch 039] batch 70/87 loss=4.6274e-01 elapsed=2.9s
#   [epoch 039] batch 80/87 loss=4.9515e-01 elapsed=3.3s
# [039] train_lp(norm)=5.4625e-01 train_rel_l2(phys)=8.5107e-02 val_rel_l2(phys)=1.0016e+00 val_rmse(phys)=3.2929e-01 lr=7.61e-04 time=4.9s test_rel_l2(phys)=1.0447e+00 test_rmse(phys)=1.0347e+00
#   [epoch 040] batch 10/87 loss=5.6722e-01 elapsed=0.4s
#   [epoch 040] batch 20/87 loss=5.3086e-01 elapsed=0.8s
#   [epoch 040] batch 30/87 loss=5.5363e-01 elapsed=1.2s
#   [epoch 040] batch 40/87 loss=5.1160e-01 elapsed=1.6s
#   [epoch 040] batch 50/87 loss=5.3329e-01 elapsed=2.1s
#   [epoch 040] batch 60/87 loss=5.1475e-01 elapsed=2.5s
#   [epoch 040] batch 70/87 loss=5.4903e-01 elapsed=2.9s
#   [epoch 040] batch 80/87 loss=6.2884e-01 elapsed=3.3s
# [040] train_lp(norm)=5.4684e-01 train_rel_l2(phys)=8.6194e-02 val_rel_l2(phys)=1.0040e+00 val_rmse(phys)=3.2995e-01 lr=7.50e-04 time=4.8s test_rel_l2(phys)=1.0699e+00 test_rmse(phys)=1.0366e+00
#   [epoch 041] batch 10/87 loss=5.1189e-01 elapsed=0.4s
#   [epoch 041] batch 20/87 loss=5.2942e-01 elapsed=0.8s
#   [epoch 041] batch 30/87 loss=5.0654e-01 elapsed=1.2s
#   [epoch 041] batch 40/87 loss=5.2709e-01 elapsed=1.6s
#   [epoch 041] batch 50/87 loss=5.1252e-01 elapsed=2.0s
#   [epoch 041] batch 60/87 loss=4.5026e-01 elapsed=2.4s
#   [epoch 041] batch 70/87 loss=5.8240e-01 elapsed=2.9s
#   [epoch 041] batch 80/87 loss=4.8945e-01 elapsed=3.3s
# [041] train_lp(norm)=5.3441e-01 train_rel_l2(phys)=8.4166e-02 val_rel_l2(phys)=1.0019e+00 val_rmse(phys)=3.2939e-01 lr=7.39e-04 time=4.8s test_rel_l2(phys)=1.0471e+00 test_rmse(phys)=1.0350e+00
#   [epoch 042] batch 10/87 loss=4.9749e-01 elapsed=0.4s
#   [epoch 042] batch 20/87 loss=5.1025e-01 elapsed=0.8s
#   [epoch 042] batch 30/87 loss=4.7389e-01 elapsed=1.3s
#   [epoch 042] batch 40/87 loss=4.9759e-01 elapsed=1.7s
#   [epoch 042] batch 50/87 loss=5.5803e-01 elapsed=2.1s
#   [epoch 042] batch 60/87 loss=7.6082e-01 elapsed=2.5s
#   [epoch 042] batch 70/87 loss=4.8349e-01 elapsed=3.0s
#   [epoch 042] batch 80/87 loss=4.6677e-01 elapsed=3.4s
# [042] train_lp(norm)=5.1728e-01 train_rel_l2(phys)=8.1169e-02 val_rel_l2(phys)=1.0017e+00 val_rmse(phys)=3.2935e-01 lr=7.27e-04 time=5.2s test_rel_l2(phys)=1.0432e+00 test_rmse(phys)=1.0349e+00
#   [epoch 043] batch 10/87 loss=5.3194e-01 elapsed=0.4s
#   [epoch 043] batch 20/87 loss=4.9176e-01 elapsed=0.9s
#   [epoch 043] batch 30/87 loss=5.0155e-01 elapsed=1.4s
#   [epoch 043] batch 40/87 loss=5.1856e-01 elapsed=1.8s
#   [epoch 043] batch 50/87 loss=5.2432e-01 elapsed=2.2s
#   [epoch 043] batch 60/87 loss=5.2167e-01 elapsed=2.6s
#   [epoch 043] batch 70/87 loss=4.3926e-01 elapsed=3.1s
#   [epoch 043] batch 80/87 loss=5.5232e-01 elapsed=3.5s
# [043] train_lp(norm)=5.1740e-01 train_rel_l2(phys)=8.1096e-02 val_rel_l2(phys)=1.0022e+00 val_rmse(phys)=3.2943e-01 lr=7.15e-04 time=5.2s test_rel_l2(phys)=1.0586e+00 test_rmse(phys)=1.0357e+00
#   [epoch 044] batch 10/87 loss=5.5782e-01 elapsed=0.4s
#   [epoch 044] batch 20/87 loss=5.2132e-01 elapsed=0.9s
#   [epoch 044] batch 30/87 loss=5.4837e-01 elapsed=1.3s
#   [epoch 044] batch 40/87 loss=6.5697e-01 elapsed=1.7s
#   [epoch 044] batch 50/87 loss=5.5489e-01 elapsed=2.2s
#   [epoch 044] batch 60/87 loss=5.2498e-01 elapsed=2.6s
#   [epoch 044] batch 70/87 loss=5.4542e-01 elapsed=3.0s
#   [epoch 044] batch 80/87 loss=5.2732e-01 elapsed=3.4s
# [044] train_lp(norm)=5.6193e-01 train_rel_l2(phys)=8.7739e-02 val_rel_l2(phys)=1.0026e+00 val_rmse(phys)=3.2955e-01 lr=7.03e-04 time=5.1s test_rel_l2(phys)=1.0621e+00 test_rmse(phys)=1.0361e+00
#   [epoch 045] batch 10/87 loss=4.5283e-01 elapsed=0.4s
#   [epoch 045] batch 20/87 loss=5.0317e-01 elapsed=0.8s
#   [epoch 045] batch 30/87 loss=4.8605e-01 elapsed=1.3s
#   [epoch 045] batch 40/87 loss=4.6113e-01 elapsed=1.8s
#   [epoch 045] batch 50/87 loss=4.2562e-01 elapsed=2.2s
#   [epoch 045] batch 60/87 loss=4.9441e-01 elapsed=2.7s
#   [epoch 045] batch 70/87 loss=5.1159e-01 elapsed=3.1s
#   [epoch 045] batch 80/87 loss=5.0540e-01 elapsed=3.5s
# [045] train_lp(norm)=4.9314e-01 train_rel_l2(phys)=7.7714e-02 val_rel_l2(phys)=1.0013e+00 val_rmse(phys)=3.2920e-01 lr=6.91e-04 time=5.2s test_rel_l2(phys)=1.0496e+00 test_rmse(phys)=1.0352e+00
#   [epoch 046] batch 10/87 loss=4.7631e-01 elapsed=0.4s
#   [epoch 046] batch 20/87 loss=4.8456e-01 elapsed=0.8s
#   [epoch 046] batch 30/87 loss=4.6686e-01 elapsed=1.3s
#   [epoch 046] batch 40/87 loss=4.1893e-01 elapsed=1.7s
#   [epoch 046] batch 50/87 loss=4.4242e-01 elapsed=2.1s
#   [epoch 046] batch 60/87 loss=4.7191e-01 elapsed=2.5s
#   [epoch 046] batch 70/87 loss=5.0548e-01 elapsed=2.9s
#   [epoch 046] batch 80/87 loss=5.0287e-01 elapsed=3.3s
# [046] train_lp(norm)=4.8974e-01 train_rel_l2(phys)=7.6842e-02 val_rel_l2(phys)=1.0021e+00 val_rmse(phys)=3.2941e-01 lr=6.79e-04 time=4.8s test_rel_l2(phys)=1.0555e+00 test_rmse(phys)=1.0353e+00
#   [epoch 047] batch 10/87 loss=5.9666e-01 elapsed=0.4s
#   [epoch 047] batch 20/87 loss=4.0801e-01 elapsed=0.8s
#   [epoch 047] batch 30/87 loss=4.8582e-01 elapsed=1.3s
#   [epoch 047] batch 40/87 loss=5.5982e-01 elapsed=1.7s
#   [epoch 047] batch 50/87 loss=4.5539e-01 elapsed=2.1s
#   [epoch 047] batch 60/87 loss=5.1087e-01 elapsed=2.5s
#   [epoch 047] batch 70/87 loss=5.7987e-01 elapsed=2.9s
#   [epoch 047] batch 80/87 loss=5.4359e-01 elapsed=3.4s
# [047] train_lp(norm)=5.0238e-01 train_rel_l2(phys)=7.8777e-02 val_rel_l2(phys)=1.0025e+00 val_rmse(phys)=3.2953e-01 lr=6.67e-04 time=4.9s test_rel_l2(phys)=1.0576e+00 test_rmse(phys)=1.0355e+00
#   [epoch 048] batch 10/87 loss=5.1029e-01 elapsed=0.4s
#   [epoch 048] batch 20/87 loss=4.0446e-01 elapsed=0.8s
#   [epoch 048] batch 30/87 loss=4.9294e-01 elapsed=1.2s
#   [epoch 048] batch 40/87 loss=5.1369e-01 elapsed=1.7s
#   [epoch 048] batch 50/87 loss=5.0704e-01 elapsed=2.1s
#   [epoch 048] batch 60/87 loss=5.1401e-01 elapsed=2.5s
#   [epoch 048] batch 70/87 loss=4.7338e-01 elapsed=2.9s
#   [epoch 048] batch 80/87 loss=4.7582e-01 elapsed=3.3s
# [048] train_lp(norm)=5.0607e-01 train_rel_l2(phys)=7.8649e-02 val_rel_l2(phys)=1.0019e+00 val_rmse(phys)=3.2938e-01 lr=6.55e-04 time=4.9s test_rel_l2(phys)=1.0525e+00 test_rmse(phys)=1.0351e+00
#   [epoch 049] batch 10/87 loss=4.0669e-01 elapsed=0.4s
#   [epoch 049] batch 20/87 loss=4.4733e-01 elapsed=0.9s
#   [epoch 049] batch 30/87 loss=4.6153e-01 elapsed=1.3s
#   [epoch 049] batch 40/87 loss=4.0562e-01 elapsed=1.7s
#   [epoch 049] batch 50/87 loss=3.7479e-01 elapsed=2.1s
#   [epoch 049] batch 60/87 loss=4.9528e-01 elapsed=2.5s
#   [epoch 049] batch 70/87 loss=5.2377e-01 elapsed=2.9s
#   [epoch 049] batch 80/87 loss=4.1548e-01 elapsed=3.3s
# [049] train_lp(norm)=4.5053e-01 train_rel_l2(phys)=7.0523e-02 val_rel_l2(phys)=1.0019e+00 val_rmse(phys)=3.2937e-01 lr=6.42e-04 time=4.9s test_rel_l2(phys)=1.0554e+00 test_rmse(phys)=1.0353e+00
#   [epoch 050] batch 10/87 loss=4.5618e-01 elapsed=0.4s
#   [epoch 050] batch 20/87 loss=3.9609e-01 elapsed=0.8s
#   [epoch 050] batch 30/87 loss=4.5047e-01 elapsed=1.2s
#   [epoch 050] batch 40/87 loss=4.3731e-01 elapsed=1.6s
#   [epoch 050] batch 50/87 loss=4.2889e-01 elapsed=2.0s
#   [epoch 050] batch 60/87 loss=4.4780e-01 elapsed=2.4s
#   [epoch 050] batch 70/87 loss=5.2953e-01 elapsed=2.9s
#   [epoch 050] batch 80/87 loss=4.2976e-01 elapsed=3.3s
# [050] train_lp(norm)=4.6407e-01 train_rel_l2(phys)=7.2692e-02 val_rel_l2(phys)=1.0020e+00 val_rmse(phys)=3.2940e-01 lr=6.29e-04 time=4.8s test_rel_l2(phys)=1.0533e+00 test_rmse(phys)=1.0353e+00
#   [epoch 051] batch 10/87 loss=4.3639e-01 elapsed=0.4s
#   [epoch 051] batch 20/87 loss=4.7539e-01 elapsed=0.8s
#   [epoch 051] batch 30/87 loss=4.7490e-01 elapsed=1.2s
#   [epoch 051] batch 40/87 loss=4.7100e-01 elapsed=1.6s
#   [epoch 051] batch 50/87 loss=4.8554e-01 elapsed=2.0s
#   [epoch 051] batch 60/87 loss=5.0122e-01 elapsed=2.4s
#   [epoch 051] batch 70/87 loss=5.3430e-01 elapsed=2.8s
#   [epoch 051] batch 80/87 loss=4.6632e-01 elapsed=3.3s
# [051] train_lp(norm)=4.8882e-01 train_rel_l2(phys)=7.6607e-02 val_rel_l2(phys)=1.0018e+00 val_rmse(phys)=3.2934e-01 lr=6.17e-04 time=4.8s test_rel_l2(phys)=1.0531e+00 test_rmse(phys)=1.0353e+00
#   [epoch 052] batch 10/87 loss=4.3504e-01 elapsed=0.5s
#   [epoch 052] batch 20/87 loss=4.3312e-01 elapsed=0.9s
#   [epoch 052] batch 30/87 loss=3.8850e-01 elapsed=1.3s
#   [epoch 052] batch 40/87 loss=4.8329e-01 elapsed=1.7s
#   [epoch 052] batch 50/87 loss=4.9164e-01 elapsed=2.1s
#   [epoch 052] batch 60/87 loss=4.4245e-01 elapsed=2.5s
#   [epoch 052] batch 70/87 loss=4.4099e-01 elapsed=2.9s
#   [epoch 052] batch 80/87 loss=4.7278e-01 elapsed=3.3s
# [052] train_lp(norm)=4.4898e-01 train_rel_l2(phys)=7.0524e-02 val_rel_l2(phys)=1.0015e+00 val_rmse(phys)=3.2927e-01 lr=6.04e-04 time=5.0s test_rel_l2(phys)=1.0502e+00 test_rmse(phys)=1.0352e+00
#   [epoch 053] batch 10/87 loss=4.2319e-01 elapsed=0.4s
#   [epoch 053] batch 20/87 loss=4.4341e-01 elapsed=0.8s
#   [epoch 053] batch 30/87 loss=4.1390e-01 elapsed=1.2s
#   [epoch 053] batch 40/87 loss=4.7963e-01 elapsed=1.6s
#   [epoch 053] batch 50/87 loss=3.8705e-01 elapsed=2.0s
#   [epoch 053] batch 60/87 loss=4.0052e-01 elapsed=2.4s
#   [epoch 053] batch 70/87 loss=3.5492e-01 elapsed=2.8s
#   [epoch 053] batch 80/87 loss=4.1489e-01 elapsed=3.2s
# [053] train_lp(norm)=4.3272e-01 train_rel_l2(phys)=6.7858e-02 val_rel_l2(phys)=1.0016e+00 val_rmse(phys)=3.2929e-01 lr=5.91e-04 time=4.8s test_rel_l2(phys)=1.0494e+00 test_rmse(phys)=1.0350e+00
#   [epoch 054] batch 10/87 loss=4.3626e-01 elapsed=0.5s
#   [epoch 054] batch 20/87 loss=4.0137e-01 elapsed=0.9s
#   [epoch 054] batch 30/87 loss=3.8627e-01 elapsed=1.2s
#   [epoch 054] batch 40/87 loss=4.2600e-01 elapsed=1.6s
#   [epoch 054] batch 50/87 loss=3.8045e-01 elapsed=2.1s
#   [epoch 054] batch 60/87 loss=4.1227e-01 elapsed=2.5s
#   [epoch 054] batch 70/87 loss=3.9945e-01 elapsed=2.9s
#   [epoch 054] batch 80/87 loss=4.2282e-01 elapsed=3.2s
# [054] train_lp(norm)=4.2366e-01 train_rel_l2(phys)=6.6654e-02 val_rel_l2(phys)=1.0016e+00 val_rmse(phys)=3.2931e-01 lr=5.78e-04 time=4.7s test_rel_l2(phys)=1.0497e+00 test_rmse(phys)=1.0350e+00
#   [epoch 055] batch 10/87 loss=4.3309e-01 elapsed=0.4s
#   [epoch 055] batch 20/87 loss=4.4004e-01 elapsed=0.7s
#   [epoch 055] batch 30/87 loss=5.0095e-01 elapsed=1.1s
#   [epoch 055] batch 40/87 loss=4.4041e-01 elapsed=1.5s
#   [epoch 055] batch 50/87 loss=3.8060e-01 elapsed=1.9s
#   [epoch 055] batch 60/87 loss=4.0613e-01 elapsed=2.3s
#   [epoch 055] batch 70/87 loss=4.9408e-01 elapsed=2.7s
#   [epoch 055] batch 80/87 loss=4.1124e-01 elapsed=3.1s
# [055] train_lp(norm)=4.2151e-01 train_rel_l2(phys)=6.6830e-02 val_rel_l2(phys)=1.0016e+00 val_rmse(phys)=3.2929e-01 lr=5.65e-04 time=4.6s test_rel_l2(phys)=1.0469e+00 test_rmse(phys)=1.0346e+00
#   [epoch 056] batch 10/87 loss=3.3877e-01 elapsed=0.4s
#   [epoch 056] batch 20/87 loss=4.2392e-01 elapsed=0.8s
#   [epoch 056] batch 30/87 loss=4.5426e-01 elapsed=1.2s
#   [epoch 056] batch 40/87 loss=4.4411e-01 elapsed=1.6s
#   [epoch 056] batch 50/87 loss=4.3831e-01 elapsed=2.1s
#   [epoch 056] batch 60/87 loss=4.2660e-01 elapsed=2.5s
#   [epoch 056] batch 70/87 loss=4.0746e-01 elapsed=2.9s
#   [epoch 056] batch 80/87 loss=3.9844e-01 elapsed=3.4s
# [056] train_lp(norm)=4.1718e-01 train_rel_l2(phys)=6.6122e-02 val_rel_l2(phys)=1.0017e+00 val_rmse(phys)=3.2931e-01 lr=5.52e-04 time=5.2s test_rel_l2(phys)=1.0479e+00 test_rmse(phys)=1.0349e+00
#   [epoch 057] batch 10/87 loss=4.7368e-01 elapsed=0.5s
#   [epoch 057] batch 20/87 loss=4.0448e-01 elapsed=0.9s
#   [epoch 057] batch 30/87 loss=3.6053e-01 elapsed=1.4s
#   [epoch 057] batch 40/87 loss=3.8863e-01 elapsed=1.8s
#   [epoch 057] batch 50/87 loss=4.5541e-01 elapsed=2.3s
#   [epoch 057] batch 60/87 loss=3.6783e-01 elapsed=2.7s
#   [epoch 057] batch 70/87 loss=4.4201e-01 elapsed=3.1s
#   [epoch 057] batch 80/87 loss=3.6593e-01 elapsed=3.5s
# [057] train_lp(norm)=4.0298e-01 train_rel_l2(phys)=6.3411e-02 val_rel_l2(phys)=1.0019e+00 val_rmse(phys)=3.2936e-01 lr=5.39e-04 time=5.1s test_rel_l2(phys)=1.0523e+00 test_rmse(phys)=1.0349e+00
#   [epoch 058] batch 10/87 loss=3.6895e-01 elapsed=0.4s
#   [epoch 058] batch 20/87 loss=4.2470e-01 elapsed=0.8s
#   [epoch 058] batch 30/87 loss=3.8992e-01 elapsed=1.2s
#   [epoch 058] batch 40/87 loss=4.1516e-01 elapsed=1.6s
#   [epoch 058] batch 50/87 loss=4.3364e-01 elapsed=2.0s
#   [epoch 058] batch 60/87 loss=3.7483e-01 elapsed=2.4s
#   [epoch 058] batch 70/87 loss=4.0439e-01 elapsed=2.8s
#   [epoch 058] batch 80/87 loss=4.2073e-01 elapsed=3.2s
# [058] train_lp(norm)=3.9127e-01 train_rel_l2(phys)=6.1474e-02 val_rel_l2(phys)=1.0014e+00 val_rmse(phys)=3.2924e-01 lr=5.26e-04 time=4.7s test_rel_l2(phys)=1.0457e+00 test_rmse(phys)=1.0345e+00
#   [epoch 059] batch 10/87 loss=3.8863e-01 elapsed=0.4s
#   [epoch 059] batch 20/87 loss=3.6544e-01 elapsed=0.7s
#   [epoch 059] batch 30/87 loss=3.9756e-01 elapsed=1.1s
#   [epoch 059] batch 40/87 loss=3.8208e-01 elapsed=1.5s
#   [epoch 059] batch 50/87 loss=3.6339e-01 elapsed=1.9s
#   [epoch 059] batch 60/87 loss=3.8098e-01 elapsed=2.2s
#   [epoch 059] batch 70/87 loss=3.6804e-01 elapsed=2.6s
#   [epoch 059] batch 80/87 loss=3.7175e-01 elapsed=3.0s
# [059] train_lp(norm)=3.9055e-01 train_rel_l2(phys)=6.1659e-02 val_rel_l2(phys)=1.0013e+00 val_rmse(phys)=3.2920e-01 lr=5.13e-04 time=4.6s test_rel_l2(phys)=1.0480e+00 test_rmse(phys)=1.0347e+00
#   [epoch 060] batch 10/87 loss=4.0380e-01 elapsed=0.4s
#   [epoch 060] batch 20/87 loss=3.5743e-01 elapsed=0.8s
#   [epoch 060] batch 30/87 loss=3.6234e-01 elapsed=1.2s
#   [epoch 060] batch 40/87 loss=3.4006e-01 elapsed=1.6s
#   [epoch 060] batch 50/87 loss=4.2046e-01 elapsed=2.0s
#   [epoch 060] batch 60/87 loss=3.9020e-01 elapsed=2.4s
#   [epoch 060] batch 70/87 loss=3.9130e-01 elapsed=2.7s
#   [epoch 060] batch 80/87 loss=4.3899e-01 elapsed=3.1s
# [060] train_lp(norm)=3.8775e-01 train_rel_l2(phys)=6.0876e-02 val_rel_l2(phys)=1.0014e+00 val_rmse(phys)=3.2923e-01 lr=5.00e-04 time=4.7s test_rel_l2(phys)=1.0451e+00 test_rmse(phys)=1.0344e+00
#   [epoch 061] batch 10/87 loss=3.8576e-01 elapsed=0.4s
#   [epoch 061] batch 20/87 loss=4.5284e-01 elapsed=0.8s
#   [epoch 061] batch 30/87 loss=3.9624e-01 elapsed=1.2s
#   [epoch 061] batch 40/87 loss=3.7715e-01 elapsed=1.6s
#   [epoch 061] batch 50/87 loss=3.5442e-01 elapsed=2.0s
#   [epoch 061] batch 60/87 loss=4.1008e-01 elapsed=2.4s
#   [epoch 061] batch 70/87 loss=3.8890e-01 elapsed=2.7s
#   [epoch 061] batch 80/87 loss=3.7776e-01 elapsed=3.1s
# [061] train_lp(norm)=3.9233e-01 train_rel_l2(phys)=6.1554e-02 val_rel_l2(phys)=1.0016e+00 val_rmse(phys)=3.2930e-01 lr=4.87e-04 time=4.7s test_rel_l2(phys)=1.0530e+00 test_rmse(phys)=1.0352e+00
#   [epoch 062] batch 10/87 loss=4.0904e-01 elapsed=0.4s
#   [epoch 062] batch 20/87 loss=3.8266e-01 elapsed=0.7s
#   [epoch 062] batch 30/87 loss=3.2812e-01 elapsed=1.1s
#   [epoch 062] batch 40/87 loss=3.7512e-01 elapsed=1.5s
#   [epoch 062] batch 50/87 loss=3.5065e-01 elapsed=1.9s
#   [epoch 062] batch 60/87 loss=4.0248e-01 elapsed=2.4s
#   [epoch 062] batch 70/87 loss=3.1810e-01 elapsed=2.8s
#   [epoch 062] batch 80/87 loss=3.7955e-01 elapsed=3.2s
# [062] train_lp(norm)=3.6697e-01 train_rel_l2(phys)=5.8076e-02 val_rel_l2(phys)=1.0015e+00 val_rmse(phys)=3.2925e-01 lr=4.74e-04 time=4.8s test_rel_l2(phys)=1.0524e+00 test_rmse(phys)=1.0349e+00
#   [epoch 063] batch 10/87 loss=3.4355e-01 elapsed=0.4s
#   [epoch 063] batch 20/87 loss=4.0834e-01 elapsed=0.8s
#   [epoch 063] batch 30/87 loss=4.0922e-01 elapsed=1.3s
#   [epoch 063] batch 40/87 loss=3.5734e-01 elapsed=1.7s
#   [epoch 063] batch 50/87 loss=3.9084e-01 elapsed=2.1s
#   [epoch 063] batch 60/87 loss=3.5228e-01 elapsed=2.4s
#   [epoch 063] batch 70/87 loss=3.6839e-01 elapsed=2.8s
#   [epoch 063] batch 80/87 loss=3.5881e-01 elapsed=3.2s
# [063] train_lp(norm)=3.7396e-01 train_rel_l2(phys)=5.9102e-02 val_rel_l2(phys)=1.0012e+00 val_rmse(phys)=3.2919e-01 lr=4.61e-04 time=4.7s test_rel_l2(phys)=1.0467e+00 test_rmse(phys)=1.0345e+00
#   [epoch 064] batch 10/87 loss=3.9847e-01 elapsed=0.4s
#   [epoch 064] batch 20/87 loss=3.3463e-01 elapsed=0.7s
#   [epoch 064] batch 30/87 loss=4.0957e-01 elapsed=1.1s
#   [epoch 064] batch 40/87 loss=3.2619e-01 elapsed=1.5s
#   [epoch 064] batch 50/87 loss=3.4789e-01 elapsed=1.9s
#   [epoch 064] batch 60/87 loss=3.7936e-01 elapsed=2.2s
#   [epoch 064] batch 70/87 loss=3.3372e-01 elapsed=2.6s
#   [epoch 064] batch 80/87 loss=3.9601e-01 elapsed=3.1s
# [064] train_lp(norm)=3.6626e-01 train_rel_l2(phys)=5.7822e-02 val_rel_l2(phys)=1.0012e+00 val_rmse(phys)=3.2918e-01 lr=4.48e-04 time=4.8s test_rel_l2(phys)=1.0482e+00 test_rmse(phys)=1.0347e+00
#   [epoch 065] batch 10/87 loss=3.4908e-01 elapsed=0.4s
#   [epoch 065] batch 20/87 loss=3.6885e-01 elapsed=0.8s
#   [epoch 065] batch 30/87 loss=3.7907e-01 elapsed=1.2s
#   [epoch 065] batch 40/87 loss=3.3703e-01 elapsed=1.6s
#   [epoch 065] batch 50/87 loss=3.5357e-01 elapsed=2.0s
#   [epoch 065] batch 60/87 loss=3.4797e-01 elapsed=2.4s
#   [epoch 065] batch 70/87 loss=3.2324e-01 elapsed=2.8s
#   [epoch 065] batch 80/87 loss=3.5833e-01 elapsed=3.2s
# [065] train_lp(norm)=3.5755e-01 train_rel_l2(phys)=5.6523e-02 val_rel_l2(phys)=1.0012e+00 val_rmse(phys)=3.2916e-01 lr=4.35e-04 time=4.9s test_rel_l2(phys)=1.0495e+00 test_rmse(phys)=1.0348e+00
#   [epoch 066] batch 10/87 loss=3.2273e-01 elapsed=0.4s
#   [epoch 066] batch 20/87 loss=3.6195e-01 elapsed=0.8s
#   [epoch 066] batch 30/87 loss=3.1071e-01 elapsed=1.2s
#   [epoch 066] batch 40/87 loss=3.2695e-01 elapsed=1.6s
#   [epoch 066] batch 50/87 loss=3.5762e-01 elapsed=2.0s
#   [epoch 066] batch 60/87 loss=3.6797e-01 elapsed=2.4s
#   [epoch 066] batch 70/87 loss=3.5368e-01 elapsed=2.8s
#   [epoch 066] batch 80/87 loss=3.6589e-01 elapsed=3.2s
# [066] train_lp(norm)=3.4576e-01 train_rel_l2(phys)=5.4661e-02 val_rel_l2(phys)=1.0009e+00 val_rmse(phys)=3.2909e-01 lr=4.22e-04 time=4.8s test_rel_l2(phys)=1.0464e+00 test_rmse(phys)=1.0346e+00
#   [epoch 067] batch 10/87 loss=3.2527e-01 elapsed=0.4s
#   [epoch 067] batch 20/87 loss=3.6544e-01 elapsed=0.8s
#   [epoch 067] batch 30/87 loss=3.1845e-01 elapsed=1.2s
#   [epoch 067] batch 40/87 loss=3.2818e-01 elapsed=1.6s
#   [epoch 067] batch 50/87 loss=3.0647e-01 elapsed=2.0s
#   [epoch 067] batch 60/87 loss=3.4431e-01 elapsed=2.4s
#   [epoch 067] batch 70/87 loss=3.4023e-01 elapsed=2.8s
#   [epoch 067] batch 80/87 loss=3.8540e-01 elapsed=3.2s
# [067] train_lp(norm)=3.3811e-01 train_rel_l2(phys)=5.3604e-02 val_rel_l2(phys)=1.0011e+00 val_rmse(phys)=3.2916e-01 lr=4.09e-04 time=4.8s test_rel_l2(phys)=1.0436e+00 test_rmse(phys)=1.0342e+00
#   [epoch 068] batch 10/87 loss=3.0228e-01 elapsed=0.4s
#   [epoch 068] batch 20/87 loss=2.9002e-01 elapsed=0.8s
#   [epoch 068] batch 30/87 loss=3.3099e-01 elapsed=1.2s
#   [epoch 068] batch 40/87 loss=3.2204e-01 elapsed=1.6s
#   [epoch 068] batch 50/87 loss=2.7510e-01 elapsed=2.0s
#   [epoch 068] batch 60/87 loss=3.1448e-01 elapsed=2.4s
#   [epoch 068] batch 70/87 loss=3.5766e-01 elapsed=2.8s
#   [epoch 068] batch 80/87 loss=3.3420e-01 elapsed=3.2s
# [068] train_lp(norm)=3.3355e-01 train_rel_l2(phys)=5.2926e-02 val_rel_l2(phys)=1.0013e+00 val_rmse(phys)=3.2921e-01 lr=3.96e-04 time=4.8s test_rel_l2(phys)=1.0511e+00 test_rmse(phys)=1.0348e+00
#   [epoch 069] batch 10/87 loss=3.2050e-01 elapsed=0.4s
#   [epoch 069] batch 20/87 loss=3.5729e-01 elapsed=0.8s
#   [epoch 069] batch 30/87 loss=3.2234e-01 elapsed=1.2s
#   [epoch 069] batch 40/87 loss=3.6726e-01 elapsed=1.6s
#   [epoch 069] batch 50/87 loss=3.4257e-01 elapsed=2.0s
#   [epoch 069] batch 60/87 loss=3.4105e-01 elapsed=2.4s
#   [epoch 069] batch 70/87 loss=2.9322e-01 elapsed=2.8s
#   [epoch 069] batch 80/87 loss=3.5015e-01 elapsed=3.2s
# [069] train_lp(norm)=3.4011e-01 train_rel_l2(phys)=5.3929e-02 val_rel_l2(phys)=1.0013e+00 val_rmse(phys)=3.2919e-01 lr=3.83e-04 time=4.8s test_rel_l2(phys)=1.0502e+00 test_rmse(phys)=1.0345e+00
#   [epoch 070] batch 10/87 loss=3.7010e-01 elapsed=0.4s
#   [epoch 070] batch 20/87 loss=3.4021e-01 elapsed=0.8s
#   [epoch 070] batch 30/87 loss=3.1646e-01 elapsed=1.2s
#   [epoch 070] batch 40/87 loss=3.3802e-01 elapsed=1.6s
#   [epoch 070] batch 50/87 loss=3.9764e-01 elapsed=2.0s
#   [epoch 070] batch 60/87 loss=2.9726e-01 elapsed=2.4s
#   [epoch 070] batch 70/87 loss=3.2729e-01 elapsed=2.8s
#   [epoch 070] batch 80/87 loss=4.1102e-01 elapsed=3.2s
# [070] train_lp(norm)=3.3088e-01 train_rel_l2(phys)=5.2516e-02 val_rel_l2(phys)=1.0009e+00 val_rmse(phys)=3.2911e-01 lr=3.71e-04 time=4.8s test_rel_l2(phys)=1.0440e+00 test_rmse(phys)=1.0342e+00
#   [epoch 071] batch 10/87 loss=2.8994e-01 elapsed=0.4s
#   [epoch 071] batch 20/87 loss=2.5898e-01 elapsed=0.8s
#   [epoch 071] batch 30/87 loss=3.0455e-01 elapsed=1.2s
#   [epoch 071] batch 40/87 loss=3.3166e-01 elapsed=1.6s
#   [epoch 071] batch 50/87 loss=3.0197e-01 elapsed=2.0s
#   [epoch 071] batch 60/87 loss=3.3790e-01 elapsed=2.4s
#   [epoch 071] batch 70/87 loss=4.6680e-01 elapsed=2.8s
#   [epoch 071] batch 80/87 loss=3.3983e-01 elapsed=3.2s
# [071] train_lp(norm)=3.2111e-01 train_rel_l2(phys)=5.0869e-02 val_rel_l2(phys)=1.0009e+00 val_rmse(phys)=3.2909e-01 lr=3.58e-04 time=4.8s test_rel_l2(phys)=1.0414e+00 test_rmse(phys)=1.0340e+00
#   [epoch 072] batch 10/87 loss=3.0266e-01 elapsed=0.4s
#   [epoch 072] batch 20/87 loss=2.9269e-01 elapsed=0.8s
#   [epoch 072] batch 30/87 loss=3.1519e-01 elapsed=1.2s
#   [epoch 072] batch 40/87 loss=2.9497e-01 elapsed=1.6s
#   [epoch 072] batch 50/87 loss=2.6538e-01 elapsed=2.0s
#   [epoch 072] batch 60/87 loss=2.8400e-01 elapsed=2.4s
#   [epoch 072] batch 70/87 loss=3.3290e-01 elapsed=2.8s
#   [epoch 072] batch 80/87 loss=3.7120e-01 elapsed=3.2s
# [072] train_lp(norm)=3.1659e-01 train_rel_l2(phys)=5.0385e-02 val_rel_l2(phys)=1.0012e+00 val_rmse(phys)=3.2918e-01 lr=3.45e-04 time=4.7s test_rel_l2(phys)=1.0485e+00 test_rmse(phys)=1.0345e+00
#   [epoch 073] batch 10/87 loss=3.6510e-01 elapsed=0.4s
#   [epoch 073] batch 20/87 loss=2.7307e-01 elapsed=0.8s
#   [epoch 073] batch 30/87 loss=2.9899e-01 elapsed=1.2s
#   [epoch 073] batch 40/87 loss=2.9323e-01 elapsed=1.6s
#   [epoch 073] batch 50/87 loss=3.2581e-01 elapsed=2.0s
#   [epoch 073] batch 60/87 loss=3.4925e-01 elapsed=2.4s
#   [epoch 073] batch 70/87 loss=3.2523e-01 elapsed=2.8s
#   [epoch 073] batch 80/87 loss=3.2516e-01 elapsed=3.2s
# [073] train_lp(norm)=3.1614e-01 train_rel_l2(phys)=5.0140e-02 val_rel_l2(phys)=1.0012e+00 val_rmse(phys)=3.2917e-01 lr=3.33e-04 time=4.8s test_rel_l2(phys)=1.0491e+00 test_rmse(phys)=1.0345e+00
#   [epoch 074] batch 10/87 loss=2.9298e-01 elapsed=0.4s
#   [epoch 074] batch 20/87 loss=3.7751e-01 elapsed=0.8s
#   [epoch 074] batch 30/87 loss=3.3183e-01 elapsed=1.2s
#   [epoch 074] batch 40/87 loss=3.4173e-01 elapsed=1.6s
#   [epoch 074] batch 50/87 loss=3.1789e-01 elapsed=2.0s
#   [epoch 074] batch 60/87 loss=3.0637e-01 elapsed=2.4s
#   [epoch 074] batch 70/87 loss=3.1987e-01 elapsed=2.8s
#   [epoch 074] batch 80/87 loss=3.3502e-01 elapsed=3.2s
# [074] train_lp(norm)=3.1644e-01 train_rel_l2(phys)=4.9930e-02 val_rel_l2(phys)=1.0009e+00 val_rmse(phys)=3.2910e-01 lr=3.21e-04 time=4.8s test_rel_l2(phys)=1.0451e+00 test_rmse(phys)=1.0342e+00
#   [epoch 075] batch 10/87 loss=3.6406e-01 elapsed=0.4s
#   [epoch 075] batch 20/87 loss=2.8030e-01 elapsed=0.8s
#   [epoch 075] batch 30/87 loss=2.4933e-01 elapsed=1.2s
#   [epoch 075] batch 40/87 loss=2.6443e-01 elapsed=1.6s
#   [epoch 075] batch 50/87 loss=3.1286e-01 elapsed=2.0s
#   [epoch 075] batch 60/87 loss=2.7674e-01 elapsed=2.4s
#   [epoch 075] batch 70/87 loss=2.8026e-01 elapsed=2.8s
#   [epoch 075] batch 80/87 loss=2.6674e-01 elapsed=3.2s
# [075] train_lp(norm)=2.9368e-01 train_rel_l2(phys)=4.6732e-02 val_rel_l2(phys)=1.0007e+00 val_rmse(phys)=3.2906e-01 lr=3.09e-04 time=4.8s test_rel_l2(phys)=1.0422e+00 test_rmse(phys)=1.0340e+00
#   [epoch 076] batch 10/87 loss=3.1209e-01 elapsed=0.4s
#   [epoch 076] batch 20/87 loss=2.7879e-01 elapsed=0.8s
#   [epoch 076] batch 30/87 loss=3.3167e-01 elapsed=1.2s
#   [epoch 076] batch 40/87 loss=3.0758e-01 elapsed=1.6s
#   [epoch 076] batch 50/87 loss=3.0214e-01 elapsed=2.0s
#   [epoch 076] batch 60/87 loss=2.9311e-01 elapsed=2.4s
#   [epoch 076] batch 70/87 loss=3.1184e-01 elapsed=2.8s
#   [epoch 076] batch 80/87 loss=2.9159e-01 elapsed=3.2s
# ...
#   [epoch 096] batch 20/87 loss=2.1844e-01 elapsed=0.8s
#   [epoch 096] batch 30/87 loss=2.3816e-01 elapsed=1.2s
#   [epoch 096] batch 40/87 loss=2.5406e-01 elapsed=1.6s
#   [epoch 096] batch 50/87 loss=2.6163e-01 elapsed=2.0s
#   [epoch 096] batch 60/87 loss=2.5262e-01 elapsed=2.4s
#   [epoch 096] batch 70/87 loss=2.3257e-01 elapsed=2.8s
#   [epoch 096] batch 80/87 loss=2.3989e-01 elapsed=3.2s
# [096] train_lp(norm)=2.3919e-01 train_rel_l2(phys)=3.8365e-02 val_rel_l2(phys)=1.0006e+00 val_rmse(phys)=3.2903e-01 lr=9.55e-05 time=4.8s test_rel_l2(phys)=1.0461e+00 test_rmse(phys)=1.0341e+00
#   [epoch 097] batch 10/87 loss=2.1764e-01 elapsed=0.4s
#   [epoch 097] batch 20/87 loss=2.2895e-01 elapsed=0.8s
#   [epoch 097] batch 30/87 loss=1.9918e-01 elapsed=1.2s
#   [epoch 097] batch 40/87 loss=2.5671e-01 elapsed=1.6s
#   [epoch 097] batch 50/87 loss=2.4183e-01 elapsed=2.0s
#   [epoch 097] batch 60/87 loss=2.7163e-01 elapsed=2.4s
#   [epoch 097] batch 70/87 loss=2.2646e-01 elapsed=2.8s
#   [epoch 097] batch 80/87 loss=2.5087e-01 elapsed=3.2s
# [097] train_lp(norm)=2.3740e-01 train_rel_l2(phys)=3.8076e-02 val_rel_l2(phys)=1.0007e+00 val_rmse(phys)=3.2904e-01 lr=8.79e-05 time=4.8s test_rel_l2(phys)=1.0459e+00 test_rmse(phys)=1.0341e+00
#   [epoch 098] batch 10/87 loss=2.0613e-01 elapsed=0.4s
#   [epoch 098] batch 20/87 loss=2.7518e-01 elapsed=0.8s
#   [epoch 098] batch 30/87 loss=2.5129e-01 elapsed=1.2s
#   [epoch 098] batch 40/87 loss=2.4514e-01 elapsed=1.6s
#   [epoch 098] batch 50/87 loss=2.1573e-01 elapsed=2.0s
#   [epoch 098] batch 60/87 loss=2.7038e-01 elapsed=2.4s
#   [epoch 098] batch 70/87 loss=2.6475e-01 elapsed=2.8s
#   [epoch 098] batch 80/87 loss=2.5099e-01 elapsed=3.2s
# [098] train_lp(norm)=2.3579e-01 train_rel_l2(phys)=3.7834e-02 val_rel_l2(phys)=1.0006e+00 val_rmse(phys)=3.2901e-01 lr=8.07e-05 time=4.9s test_rel_l2(phys)=1.0457e+00 test_rmse(phys)=1.0341e+00
#   [epoch 099] batch 10/87 loss=1.9945e-01 elapsed=0.4s
#   [epoch 099] batch 20/87 loss=2.3016e-01 elapsed=0.8s
#   [epoch 099] batch 30/87 loss=2.4356e-01 elapsed=1.2s
#   [epoch 099] batch 40/87 loss=2.2230e-01 elapsed=1.6s
#   [epoch 099] batch 50/87 loss=2.3599e-01 elapsed=2.0s
#   [epoch 099] batch 60/87 loss=2.1922e-01 elapsed=2.4s
#   [epoch 099] batch 70/87 loss=2.5075e-01 elapsed=2.8s
#   [epoch 099] batch 80/87 loss=2.0888e-01 elapsed=3.2s
# [099] train_lp(norm)=2.3470e-01 train_rel_l2(phys)=3.7673e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2901e-01 lr=7.37e-05 time=4.8s test_rel_l2(phys)=1.0442e+00 test_rmse(phys)=1.0340e+00
#   [epoch 100] batch 10/87 loss=2.4272e-01 elapsed=0.4s
#   [epoch 100] batch 20/87 loss=2.4033e-01 elapsed=0.8s
#   [epoch 100] batch 30/87 loss=2.3961e-01 elapsed=1.2s
#   [epoch 100] batch 40/87 loss=2.4646e-01 elapsed=1.6s
#   [epoch 100] batch 50/87 loss=2.1043e-01 elapsed=2.0s
#   [epoch 100] batch 60/87 loss=2.1038e-01 elapsed=2.4s
#   [epoch 100] batch 70/87 loss=2.4579e-01 elapsed=2.9s
#   [epoch 100] batch 80/87 loss=1.9942e-01 elapsed=3.3s
# [100] train_lp(norm)=2.3333e-01 train_rel_l2(phys)=3.7490e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2900e-01 lr=6.70e-05 time=4.9s test_rel_l2(phys)=1.0457e+00 test_rmse(phys)=1.0341e+00
#   [epoch 101] batch 10/87 loss=2.4499e-01 elapsed=0.4s
#   [epoch 101] batch 20/87 loss=1.9838e-01 elapsed=0.8s
#   [epoch 101] batch 30/87 loss=2.2933e-01 elapsed=1.2s
#   [epoch 101] batch 40/87 loss=1.9961e-01 elapsed=1.6s
#   [epoch 101] batch 50/87 loss=2.3690e-01 elapsed=2.0s
#   [epoch 101] batch 60/87 loss=2.1615e-01 elapsed=2.4s
#   [epoch 101] batch 70/87 loss=2.5065e-01 elapsed=2.8s
#   [epoch 101] batch 80/87 loss=3.1076e-01 elapsed=3.2s
# [101] train_lp(norm)=2.3258e-01 train_rel_l2(phys)=3.7335e-02 val_rel_l2(phys)=1.0006e+00 val_rmse(phys)=3.2901e-01 lr=6.06e-05 time=4.8s test_rel_l2(phys)=1.0455e+00 test_rmse(phys)=1.0340e+00
#   [epoch 102] batch 10/87 loss=2.0698e-01 elapsed=0.4s
#   [epoch 102] batch 20/87 loss=2.5261e-01 elapsed=0.8s
#   [epoch 102] batch 30/87 loss=2.1114e-01 elapsed=1.2s
#   [epoch 102] batch 40/87 loss=2.2485e-01 elapsed=1.6s
#   [epoch 102] batch 50/87 loss=2.5743e-01 elapsed=2.0s
#   [epoch 102] batch 60/87 loss=2.2855e-01 elapsed=2.4s
#   [epoch 102] batch 70/87 loss=2.5310e-01 elapsed=2.8s
#   [epoch 102] batch 80/87 loss=2.4232e-01 elapsed=3.2s
# [102] train_lp(norm)=2.3151e-01 train_rel_l2(phys)=3.7177e-02 val_rel_l2(phys)=1.0006e+00 val_rmse(phys)=3.2902e-01 lr=5.45e-05 time=4.8s test_rel_l2(phys)=1.0463e+00 test_rmse(phys)=1.0341e+00
#   [epoch 103] batch 10/87 loss=2.4443e-01 elapsed=0.4s
#   [epoch 103] batch 20/87 loss=2.2004e-01 elapsed=0.8s
#   [epoch 103] batch 30/87 loss=2.2224e-01 elapsed=1.2s
#   [epoch 103] batch 40/87 loss=2.3231e-01 elapsed=1.6s
#   [epoch 103] batch 50/87 loss=2.1723e-01 elapsed=2.0s
#   [epoch 103] batch 60/87 loss=2.0781e-01 elapsed=2.4s
#   [epoch 103] batch 70/87 loss=2.2944e-01 elapsed=2.8s
#   [epoch 103] batch 80/87 loss=2.2441e-01 elapsed=3.2s
# [103] train_lp(norm)=2.3020e-01 train_rel_l2(phys)=3.6986e-02 val_rel_l2(phys)=1.0006e+00 val_rmse(phys)=3.2902e-01 lr=4.87e-05 time=4.8s test_rel_l2(phys)=1.0454e+00 test_rmse(phys)=1.0340e+00
#   [epoch 104] batch 10/87 loss=2.0971e-01 elapsed=0.4s
#   [epoch 104] batch 20/87 loss=2.2189e-01 elapsed=0.8s
#   [epoch 104] batch 30/87 loss=1.8880e-01 elapsed=1.2s
#   [epoch 104] batch 40/87 loss=2.4361e-01 elapsed=1.6s
#   [epoch 104] batch 50/87 loss=2.3403e-01 elapsed=2.0s
#   [epoch 104] batch 60/87 loss=2.3576e-01 elapsed=2.4s
#   [epoch 104] batch 70/87 loss=2.1527e-01 elapsed=2.8s
#   [epoch 104] batch 80/87 loss=2.3717e-01 elapsed=3.2s
# [104] train_lp(norm)=2.2946e-01 train_rel_l2(phys)=3.6874e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2901e-01 lr=4.32e-05 time=4.8s test_rel_l2(phys)=1.0443e+00 test_rmse(phys)=1.0340e+00
#   [epoch 105] batch 10/87 loss=2.2500e-01 elapsed=0.4s
#   [epoch 105] batch 20/87 loss=2.4419e-01 elapsed=0.8s
#   [epoch 105] batch 30/87 loss=2.2896e-01 elapsed=1.2s
#   [epoch 105] batch 40/87 loss=2.5071e-01 elapsed=1.6s
#   [epoch 105] batch 50/87 loss=2.3916e-01 elapsed=2.0s
#   [epoch 105] batch 60/87 loss=2.3568e-01 elapsed=2.4s
#   [epoch 105] batch 70/87 loss=2.3239e-01 elapsed=2.8s
#   [epoch 105] batch 80/87 loss=2.1969e-01 elapsed=3.2s
# [105] train_lp(norm)=2.2895e-01 train_rel_l2(phys)=3.6791e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2900e-01 lr=3.81e-05 time=4.7s test_rel_l2(phys)=1.0447e+00 test_rmse(phys)=1.0340e+00
#   [epoch 106] batch 10/87 loss=2.4660e-01 elapsed=0.4s
#   [epoch 106] batch 20/87 loss=2.2181e-01 elapsed=0.8s
#   [epoch 106] batch 30/87 loss=2.3519e-01 elapsed=1.2s
#   [epoch 106] batch 40/87 loss=2.4888e-01 elapsed=1.6s
#   [epoch 106] batch 50/87 loss=2.1064e-01 elapsed=2.0s
#   [epoch 106] batch 60/87 loss=2.1265e-01 elapsed=2.4s
#   [epoch 106] batch 70/87 loss=2.4393e-01 elapsed=2.8s
#   [epoch 106] batch 80/87 loss=2.4998e-01 elapsed=3.2s
# [106] train_lp(norm)=2.2804e-01 train_rel_l2(phys)=3.6652e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2900e-01 lr=3.32e-05 time=4.8s test_rel_l2(phys)=1.0445e+00 test_rmse(phys)=1.0340e+00
#   [epoch 107] batch 10/87 loss=2.5586e-01 elapsed=0.4s
#   [epoch 107] batch 20/87 loss=2.3086e-01 elapsed=0.8s
#   [epoch 107] batch 30/87 loss=2.3003e-01 elapsed=1.2s
#   [epoch 107] batch 40/87 loss=2.4862e-01 elapsed=1.6s
#   [epoch 107] batch 50/87 loss=1.9083e-01 elapsed=2.0s
#   [epoch 107] batch 60/87 loss=2.6038e-01 elapsed=2.4s
#   [epoch 107] batch 70/87 loss=2.1115e-01 elapsed=2.8s
#   [epoch 107] batch 80/87 loss=2.3123e-01 elapsed=3.2s
# [107] train_lp(norm)=2.2758e-01 train_rel_l2(phys)=3.6582e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2900e-01 lr=2.87e-05 time=4.8s test_rel_l2(phys)=1.0452e+00 test_rmse(phys)=1.0340e+00
#   [epoch 108] batch 10/87 loss=2.6668e-01 elapsed=0.4s
#   [epoch 108] batch 20/87 loss=2.1792e-01 elapsed=0.8s
#   [epoch 108] batch 30/87 loss=2.2770e-01 elapsed=1.2s
#   [epoch 108] batch 40/87 loss=2.2863e-01 elapsed=1.6s
#   [epoch 108] batch 50/87 loss=2.4500e-01 elapsed=2.0s
#   [epoch 108] batch 60/87 loss=1.9159e-01 elapsed=2.4s
#   [epoch 108] batch 70/87 loss=2.4497e-01 elapsed=2.8s
#   [epoch 108] batch 80/87 loss=2.2477e-01 elapsed=3.2s
# [108] train_lp(norm)=2.2686e-01 train_rel_l2(phys)=3.6478e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2899e-01 lr=2.45e-05 time=4.8s test_rel_l2(phys)=1.0445e+00 test_rmse(phys)=1.0340e+00
#   [epoch 109] batch 10/87 loss=2.0922e-01 elapsed=0.4s
#   [epoch 109] batch 20/87 loss=2.2289e-01 elapsed=0.8s
#   [epoch 109] batch 30/87 loss=2.0792e-01 elapsed=1.2s
#   [epoch 109] batch 40/87 loss=2.1276e-01 elapsed=1.6s
#   [epoch 109] batch 50/87 loss=2.3162e-01 elapsed=2.0s
#   [epoch 109] batch 60/87 loss=2.4304e-01 elapsed=2.4s
#   [epoch 109] batch 70/87 loss=2.4159e-01 elapsed=2.8s
#   [epoch 109] batch 80/87 loss=2.1760e-01 elapsed=3.2s
# [109] train_lp(norm)=2.2619e-01 train_rel_l2(phys)=3.6351e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2899e-01 lr=2.06e-05 time=4.8s test_rel_l2(phys)=1.0451e+00 test_rmse(phys)=1.0340e+00
#   [epoch 110] batch 10/87 loss=2.2823e-01 elapsed=0.4s
#   [epoch 110] batch 20/87 loss=2.2645e-01 elapsed=0.8s
#   [epoch 110] batch 30/87 loss=2.1813e-01 elapsed=1.2s
#   [epoch 110] batch 40/87 loss=2.3530e-01 elapsed=1.6s
#   [epoch 110] batch 50/87 loss=2.2514e-01 elapsed=2.0s
#   [epoch 110] batch 60/87 loss=2.3453e-01 elapsed=2.4s
#   [epoch 110] batch 70/87 loss=2.0776e-01 elapsed=2.8s
#   [epoch 110] batch 80/87 loss=2.4024e-01 elapsed=3.2s
# [110] train_lp(norm)=2.2600e-01 train_rel_l2(phys)=3.6342e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2899e-01 lr=1.70e-05 time=4.8s test_rel_l2(phys)=1.0448e+00 test_rmse(phys)=1.0340e+00
#   [epoch 111] batch 10/87 loss=2.2374e-01 elapsed=0.4s
#   [epoch 111] batch 20/87 loss=1.8788e-01 elapsed=0.8s
#   [epoch 111] batch 30/87 loss=2.1685e-01 elapsed=1.2s
#   [epoch 111] batch 40/87 loss=2.2935e-01 elapsed=1.6s
#   [epoch 111] batch 50/87 loss=2.4479e-01 elapsed=2.0s
#   [epoch 111] batch 60/87 loss=2.3163e-01 elapsed=2.4s
#   [epoch 111] batch 70/87 loss=2.2039e-01 elapsed=2.8s
#   [epoch 111] batch 80/87 loss=2.2257e-01 elapsed=3.2s
# [111] train_lp(norm)=2.2515e-01 train_rel_l2(phys)=3.6226e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2899e-01 lr=1.38e-05 time=4.8s test_rel_l2(phys)=1.0448e+00 test_rmse(phys)=1.0340e+00
#   [epoch 112] batch 10/87 loss=2.4989e-01 elapsed=0.4s
#   [epoch 112] batch 20/87 loss=2.2862e-01 elapsed=0.8s
#   [epoch 112] batch 30/87 loss=2.1723e-01 elapsed=1.2s
#   [epoch 112] batch 40/87 loss=2.0509e-01 elapsed=1.6s
#   [epoch 112] batch 50/87 loss=2.0570e-01 elapsed=2.0s
#   [epoch 112] batch 60/87 loss=2.3282e-01 elapsed=2.4s
#   [epoch 112] batch 70/87 loss=1.9047e-01 elapsed=2.8s
#   [epoch 112] batch 80/87 loss=2.1628e-01 elapsed=3.2s
# [112] train_lp(norm)=2.2486e-01 train_rel_l2(phys)=3.6172e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2900e-01 lr=1.09e-05 time=4.8s test_rel_l2(phys)=1.0448e+00 test_rmse(phys)=1.0340e+00
#   [epoch 113] batch 10/87 loss=2.3556e-01 elapsed=0.4s
#   [epoch 113] batch 20/87 loss=2.1889e-01 elapsed=0.8s
#   [epoch 113] batch 30/87 loss=1.9335e-01 elapsed=1.2s
#   [epoch 113] batch 40/87 loss=2.5606e-01 elapsed=1.6s
#   [epoch 113] batch 50/87 loss=2.2415e-01 elapsed=2.0s
#   [epoch 113] batch 60/87 loss=1.9932e-01 elapsed=2.4s
#   [epoch 113] batch 70/87 loss=2.4227e-01 elapsed=2.8s
#   [epoch 113] batch 80/87 loss=2.5563e-01 elapsed=3.2s
# [113] train_lp(norm)=2.2484e-01 train_rel_l2(phys)=3.6167e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2900e-01 lr=8.37e-06 time=4.8s test_rel_l2(phys)=1.0451e+00 test_rmse(phys)=1.0340e+00
#   [epoch 114] batch 10/87 loss=2.0261e-01 elapsed=0.4s
#   [epoch 114] batch 20/87 loss=2.0610e-01 elapsed=0.8s
#   [epoch 114] batch 30/87 loss=2.5688e-01 elapsed=1.2s
#   [epoch 114] batch 40/87 loss=2.0782e-01 elapsed=1.6s
#   [epoch 114] batch 50/87 loss=2.3306e-01 elapsed=2.0s
#   [epoch 114] batch 60/87 loss=2.1321e-01 elapsed=2.4s
#   [epoch 114] batch 70/87 loss=1.9510e-01 elapsed=2.8s
#   [epoch 114] batch 80/87 loss=2.1308e-01 elapsed=3.2s
# [114] train_lp(norm)=2.2462e-01 train_rel_l2(phys)=3.6132e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2900e-01 lr=6.16e-06 time=4.8s test_rel_l2(phys)=1.0450e+00 test_rmse(phys)=1.0340e+00
#   [epoch 115] batch 10/87 loss=2.0471e-01 elapsed=0.4s
#   [epoch 115] batch 20/87 loss=2.1117e-01 elapsed=0.8s
#   [epoch 115] batch 30/87 loss=1.8234e-01 elapsed=1.2s
#   [epoch 115] batch 40/87 loss=2.1568e-01 elapsed=1.6s
#   [epoch 115] batch 50/87 loss=2.1267e-01 elapsed=2.0s
#   [epoch 115] batch 60/87 loss=2.2503e-01 elapsed=2.4s
#   [epoch 115] batch 70/87 loss=1.8156e-01 elapsed=2.8s
#   [epoch 115] batch 80/87 loss=2.6193e-01 elapsed=3.2s
# [115] train_lp(norm)=2.2395e-01 train_rel_l2(phys)=3.6037e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2900e-01 lr=4.28e-06 time=4.7s test_rel_l2(phys)=1.0450e+00 test_rmse(phys)=1.0340e+00
#   [epoch 116] batch 10/87 loss=2.6030e-01 elapsed=0.4s
#   [epoch 116] batch 20/87 loss=2.2879e-01 elapsed=0.8s
#   [epoch 116] batch 30/87 loss=2.2706e-01 elapsed=1.2s
#   [epoch 116] batch 40/87 loss=2.0471e-01 elapsed=1.6s
#   [epoch 116] batch 50/87 loss=2.2336e-01 elapsed=2.0s
#   [epoch 116] batch 60/87 loss=2.4926e-01 elapsed=2.4s
#   [epoch 116] batch 70/87 loss=2.2541e-01 elapsed=2.8s
#   [epoch 116] batch 80/87 loss=2.7862e-01 elapsed=3.2s
# [116] train_lp(norm)=2.2400e-01 train_rel_l2(phys)=3.6027e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2900e-01 lr=2.74e-06 time=4.8s test_rel_l2(phys)=1.0449e+00 test_rmse(phys)=1.0340e+00
#   [epoch 117] batch 10/87 loss=2.2197e-01 elapsed=0.4s
#   [epoch 117] batch 20/87 loss=2.1609e-01 elapsed=0.8s
#   [epoch 117] batch 30/87 loss=2.5249e-01 elapsed=1.2s
#   [epoch 117] batch 40/87 loss=2.2268e-01 elapsed=1.6s
#   [epoch 117] batch 50/87 loss=1.9405e-01 elapsed=2.0s
#   [epoch 117] batch 60/87 loss=2.3856e-01 elapsed=2.4s
#   [epoch 117] batch 70/87 loss=2.2519e-01 elapsed=2.8s
#   [epoch 117] batch 80/87 loss=2.2105e-01 elapsed=3.2s
# [117] train_lp(norm)=2.2373e-01 train_rel_l2(phys)=3.6001e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2900e-01 lr=1.54e-06 time=4.8s test_rel_l2(phys)=1.0450e+00 test_rmse(phys)=1.0340e+00
#   [epoch 118] batch 10/87 loss=2.2537e-01 elapsed=0.4s
#   [epoch 118] batch 20/87 loss=1.8531e-01 elapsed=0.8s
#   [epoch 118] batch 30/87 loss=2.2100e-01 elapsed=1.2s
#   [epoch 118] batch 40/87 loss=2.1045e-01 elapsed=1.6s
#   [epoch 118] batch 50/87 loss=1.9421e-01 elapsed=2.0s
#   [epoch 118] batch 60/87 loss=1.9289e-01 elapsed=2.4s
#   [epoch 118] batch 70/87 loss=2.8127e-01 elapsed=2.8s
#   [epoch 118] batch 80/87 loss=2.2533e-01 elapsed=3.2s
# [118] train_lp(norm)=2.2369e-01 train_rel_l2(phys)=3.5991e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2900e-01 lr=6.85e-07 time=4.8s test_rel_l2(phys)=1.0450e+00 test_rmse(phys)=1.0340e+00
#   [epoch 119] batch 10/87 loss=2.3573e-01 elapsed=0.4s
#   [epoch 119] batch 20/87 loss=2.2583e-01 elapsed=0.8s
#   [epoch 119] batch 30/87 loss=1.9812e-01 elapsed=1.2s
#   [epoch 119] batch 40/87 loss=2.5606e-01 elapsed=1.6s
#   [epoch 119] batch 50/87 loss=2.1771e-01 elapsed=2.0s
#   [epoch 119] batch 60/87 loss=2.3045e-01 elapsed=2.4s
#   [epoch 119] batch 70/87 loss=2.2283e-01 elapsed=2.8s
#   [epoch 119] batch 80/87 loss=2.1108e-01 elapsed=3.2s
# [119] train_lp(norm)=2.2360e-01 train_rel_l2(phys)=3.5982e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2900e-01 lr=1.71e-07 time=4.8s test_rel_l2(phys)=1.0450e+00 test_rmse(phys)=1.0340e+00
#   [epoch 120] batch 10/87 loss=1.9895e-01 elapsed=0.4s
#   [epoch 120] batch 20/87 loss=2.2340e-01 elapsed=0.8s
#   [epoch 120] batch 30/87 loss=2.1983e-01 elapsed=1.2s
#   [epoch 120] batch 40/87 loss=1.9214e-01 elapsed=1.6s
#   [epoch 120] batch 50/87 loss=2.3563e-01 elapsed=2.0s
#   [epoch 120] batch 60/87 loss=2.0960e-01 elapsed=2.4s
#   [epoch 120] batch 70/87 loss=2.0806e-01 elapsed=2.8s
#   [epoch 120] batch 80/87 loss=2.2577e-01 elapsed=3.2s
# [120] train_lp(norm)=2.2373e-01 train_rel_l2(phys)=3.5996e-02 val_rel_l2(phys)=1.0005e+00 val_rmse(phys)=3.2900e-01 lr=0.00e+00 time=4.8s test_rel_l2(phys)=1.0450e+00 test_rmse(phys)=1.0340e+00
# Best val rel-L2: 1.0005e+00
# Checkpoint: C:\Users\TCZ\Desktop\Neeraj\Flow-reconstruction-in-VPM-using-FNO-main\results\fno_randomdist_time_folder_3d_best_model.pt

# %%
# =========================
# Post-training test snippet (load best checkpoint and test)
# =========================
if not HAS_TEST and not HAS_TEST_SR:
    print("[skip] No test or test_sr split available. Fill CFG['test_dirs'] or 'test_sr_dirs' and rerun.")
else:
    try:
        ckpt = torch.load(CKPT_PATH, map_location=DEVICE, weights_only=False)
    except TypeError:
        ckpt = torch.load(CKPT_PATH, map_location=DEVICE)

    state_dict = ckpt['model_state_dict'] if isinstance(ckpt, dict) and 'model_state_dict' in ckpt else ckpt
    MODEL.load_state_dict(state_dict)
    MODEL.eval()

    test_m = evaluate(MODEL, TEST_LOADER, collect=True) if HAS_TEST else None
    test_sr_m = evaluate(MODEL, TEST_SR_LOADER, collect=True) if HAS_TEST_SR else None
    print('Loaded checkpoint:', CKPT_PATH)
    if isinstance(ckpt, dict):
        print('Checkpoint best val rel-L2:', ckpt.get('best_val_rel_l2', 'n/a'))
    else:
        print('Checkpoint best val rel-L2: n/a (state_dict only)')
    if test_m is not None:
        print(
            f"Post-train TEST metrics -> rel-L2={test_m['rel_l2']:.4e}, "
            f"RMSE={test_m['rmse']:.4e}, MAE={test_m['mae']:.4e}, MSE={test_m['mse']:.4e}"
        )
    if test_sr_m is not None:
        print(
            f"Post-train TEST_SR metrics -> rel-L2={test_sr_m['rel_l2']:.4e}, "
            f"RMSE={test_sr_m['rmse']:.4e}, MAE={test_sr_m['mae']:.4e}, MSE={test_sr_m['mse']:.4e}"
        )
# Out:
# Loaded checkpoint: C:\Users\TCZ\Desktop\Neeraj\Flow-reconstruction-in-VPM-using-FNO-main\results\fno_randomdist_time_folder_3d_best_model.pt
# Checkpoint best val rel-L2: 1.000479677071174
# Post-train TEST metrics -> rel-L2=1.0448e+00, RMSE=1.0340e+00, MAE=4.5616e-01, MSE=1.4951e+00

# %%
# =========================
# Primary plots (Convergence + Reconstruction Timeline + 3D planes)
# =========================
from matplotlib.colors import LogNorm
from matplotlib.ticker import MaxNLocator, AutoMinorLocator, FormatStrFormatter

if CFG.get('use_best_checkpoint_for_reports', True) and CKPT_PATH.exists():
    try:
        ckpt = torch.load(CKPT_PATH, map_location=DEVICE, weights_only=False)
    except TypeError:
        ckpt = torch.load(CKPT_PATH, map_location=DEVICE)
    state_dict = ckpt['model_state_dict'] if isinstance(ckpt, dict) and 'model_state_dict' in ckpt else ckpt
    MODEL.load_state_dict(state_dict)
    MODEL.eval()
    print('[info] loaded best checkpoint for reporting:', CKPT_PATH)

FIELD_CMAP = CFG.get('plot_field_cmap', 'viridis')
ERROR_CMAP = CFG.get('plot_error_cmap', 'magma')


def speed_from_velocity(u_chw):
    # Convert velocity channels [Ux, Uy, Uz] to scalar speed [Nx, Ny, Nz].
    return torch.linalg.norm(u_chw, dim=0).cpu().numpy()


def xz_max_projection(vol):
    return np.max(vol, axis=1)


def orthogonal_max_projections(vol):
    return {
        'XY max over z': np.max(vol, axis=2).T,
        'XZ max over y': np.max(vol, axis=1).T,
        'YZ max over x': np.max(vol, axis=0).T,
    }


def style_axis_with_dense_ticks(ax, x_count, y_count, n_ticks=6):
    xt = np.linspace(0, max(x_count - 1, 0), num=min(n_ticks, max(x_count, 1)), dtype=int)
    yt = np.linspace(0, max(y_count - 1, 0), num=min(n_ticks, max(y_count, 1)), dtype=int)
    ax.set_xticks(np.unique(xt))
    ax.set_yticks(np.unique(yt))
    ax.tick_params(axis='both', which='major', labelsize=8)


def style_curve_axis(ax, xlabel, ylabel):
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.xaxis.set_major_locator(MaxNLocator(nbins=8, integer=True))
    ax.yaxis.set_major_locator(MaxNLocator(nbins=8))
    ax.yaxis.set_minor_locator(AutoMinorLocator(2))
    ax.grid(True, which='major', alpha=0.35)
    ax.grid(True, which='minor', alpha=0.20, linestyle='--')


@torch.no_grad()
def sample_prediction(ds, files, idx):
    x_norm, y_norm = ds[idx]
    p_norm = predict(MODEL, x_norm.unsqueeze(0).to(DEVICE, non_blocking=NON_BLOCKING))[0].cpu()

    y_phys = to_physical_y(y_norm)
    p_phys = to_physical_y(p_norm)
    true_speed = speed_from_velocity(y_phys)
    pred_speed = speed_from_velocity(p_phys)
    err_speed = np.abs(pred_speed - true_speed)
    rel = (
        torch.linalg.norm((p_phys - y_phys).reshape(-1))
        / torch.linalg.norm(y_phys.reshape(-1)).clamp_min(1e-12)
    ).item()
    fp = Path(files[idx])
    return {
        'idx': idx,
        'frame': parse_frame_id(fp),
        'folder': fp.parent.name,
        'file': fp.name,
        'true_speed': true_speed,
        'pred_speed': pred_speed,
        'err_speed': err_speed,
        'rel_l2': rel,
    }


def choose_distant_indices_same_folder(files, min_frame=0, n_cols=4, fractions=None, start_frac=0.10, preferred_folder=None):
    rows = []
    for i, f in enumerate(files):
        fr = parse_frame_id(f)
        if min_frame not in (None, 0) and fr < min_frame:
            continue
        fp = Path(f)
        rows.append((i, fp.parent.name, fr, f))

    if len(rows) == 0:
        return None, []

    grouped = defaultdict(list)
    for r in rows:
        grouped[r[1]].append(r)
    for k in grouped:
        grouped[k] = sorted(grouped[k], key=lambda t: t[2])

    chosen_folder = preferred_folder if preferred_folder in grouped else max(grouped.keys(), key=lambda k: len(grouped[k]))
    folder_rows = grouped[chosen_folder]
    if len(folder_rows) == 0:
        return chosen_folder, []

    start_idx = max(1, int(round(start_frac * max(len(folder_rows) - 1, 1))))
    cand = folder_rows[start_idx:] if start_idx < len(folder_rows) else folder_rows
    if len(cand) == 0:
        cand = folder_rows

    if fractions is None:
        fractions = [0.18, 0.42, 0.70, 0.92]
    fractions = list(fractions)[:n_cols]
    if len(fractions) < n_cols:
        fractions = fractions + [fractions[-1]] * (n_cols - len(fractions))

    pos = [int(round(f * (len(cand) - 1))) for f in fractions]
    pos = [max(0, min(len(cand) - 1, p)) for p in pos]

    # Deduplicate while preserving order, then fill if needed.
    uniq = []
    for p in pos:
        if p not in uniq:
            uniq.append(p)
    k = 0
    while len(uniq) < min(n_cols, len(cand)):
        if k not in uniq:
            uniq.append(k)
        k += 1

    uniq = uniq[:min(n_cols, len(cand))]
    selected = [cand[p][0] for p in uniq]
    return chosen_folder, selected


def plot_timeline_3x4(ds, files, split_name, min_frame, preferred_folder, save_tag):
    if ds is None or len(files) == 0:
        print(f'[skip] {split_name}: empty split')
        return None

    folder_name, idxs = choose_distant_indices_same_folder(
        files,
        min_frame=min_frame,
        n_cols=int(CFG.get('timeline_n_cols', 4)),
        fractions=CFG.get('timeline_fractions', [0.18, 0.42, 0.70, 0.92]),
        start_frac=float(CFG.get('timeline_start_frac', 0.10)),
        preferred_folder=preferred_folder,
    )
    if len(idxs) == 0:
        print(f'[skip] {split_name}: no valid snapshot indices selected')
        return None

    print(f"[{split_name}] timeline folder={folder_name}, selected idx={idxs}")
    print('[note] idx = position in split list; frame = simulation timestep parsed from filename.')
    print('[note] These panels use max projection over y (entire y-domain), so no active-y slice index is used.')

    samples = [sample_prediction(ds, files, i) for i in idxs]
    true_proj = [xz_max_projection(s['true_speed']) for s in samples]
    pred_proj = [xz_max_projection(s['pred_speed']) for s in samples]
    err_proj = [xz_max_projection(s['err_speed']) for s in samples]

    all_field_vals = np.concatenate([a.reshape(-1) for a in (true_proj + pred_proj)])
    field_vmin = float(np.min(all_field_vals))
    field_vmax = float(np.max(all_field_vals))

    all_err_vals = np.concatenate([a.reshape(-1) for a in err_proj])
    err_vmin = max(float(np.min(all_err_vals)), 1e-8)
    err_vmax = max(float(np.max(all_err_vals)), err_vmin * 10.0)

    n_cols = len(samples)
    fig, axs = plt.subplots(3, n_cols, figsize=(4.2 * n_cols, 10.2), constrained_layout=True)
    if n_cols == 1:
        axs = np.asarray(axs).reshape(3, 1)

    for j, s in enumerate(samples):
        t = true_proj[j]
        p = pred_proj[j]
        e = err_proj[j]

        im_t = axs[0, j].imshow(t.T, cmap=FIELD_CMAP, vmin=field_vmin, vmax=field_vmax, origin='lower', aspect='auto')
        im_p = axs[1, j].imshow(p.T, cmap=FIELD_CMAP, vmin=field_vmin, vmax=field_vmax, origin='lower', aspect='auto')
        im_e = axs[2, j].imshow(e.T, cmap=ERROR_CMAP, norm=LogNorm(vmin=err_vmin, vmax=err_vmax), origin='lower', aspect='auto')

        axs[0, j].set_title(f"t={s['frame']} (idx={s['idx']})", fontsize=10)
        style_axis_with_dense_ticks(axs[0, j], t.shape[0], t.shape[1], n_ticks=6)
        style_axis_with_dense_ticks(axs[1, j], p.shape[0], p.shape[1], n_ticks=6)
        style_axis_with_dense_ticks(axs[2, j], e.shape[0], e.shape[1], n_ticks=6)
        axs[2, j].set_xlabel('x index')

        if j == 0:
            axs[0, j].set_ylabel('z index\nTrue speed')
            axs[1, j].set_ylabel('z index\nFNO pred speed')
            axs[2, j].set_ylabel('z index\n|Pointwise error|')

    cbar_field = fig.colorbar(im_t, ax=axs[0, :].tolist() + axs[1, :].tolist(), fraction=0.018, pad=0.01)
    cbar_field.set_label('Speed magnitude')
    cbar_err = fig.colorbar(im_e, ax=axs[2, :].tolist(), fraction=0.018, pad=0.01)
    cbar_err.set_label('|Error|')

    rels = [s['rel_l2'] for s in samples]
    fig.suptitle(
        f"{split_name} 3x{n_cols} timeline | folder={folder_name} | rel-L2 median={np.median(rels):.3e}",
        fontsize=13,
    )
    save_fig(fig, f'qualitative_{save_tag}_timeline_3x{n_cols}.png')
    plt.show()

    for s in samples:
        print(f"  {split_name}: folder={s['folder']} frame={s['frame']} idx={s['idx']} rel-L2={s['rel_l2']:.3e} file={s['file']}")

    return {'folder': folder_name, 'selected_indices': idxs, 'samples': samples}


def plot_orthogonal_planes(ds, files, split_name, sample_idx, save_tag):
    if ds is None or len(files) == 0:
        return
    s = sample_prediction(ds, files, sample_idx)
    tp = orthogonal_max_projections(s['true_speed'])
    pp = orthogonal_max_projections(s['pred_speed'])
    ep = orthogonal_max_projections(s['err_speed'])

    all_field_vals = np.concatenate([v.reshape(-1) for v in list(tp.values()) + list(pp.values())])
    field_vmin = float(np.min(all_field_vals))
    field_vmax = float(np.max(all_field_vals))
    all_err_vals = np.concatenate([v.reshape(-1) for v in ep.values()])
    err_vmin = max(float(np.min(all_err_vals)), 1e-8)
    err_vmax = max(float(np.max(all_err_vals)), err_vmin * 10.0)

    fig, axs = plt.subplots(3, 3, figsize=(13, 11), constrained_layout=True)
    names = list(tp.keys())
    for j, name in enumerate(names):
        t = tp[name]
        p = pp[name]
        e = ep[name]
        im_t = axs[0, j].imshow(t, cmap=FIELD_CMAP, vmin=field_vmin, vmax=field_vmax, origin='lower', aspect='auto')
        im_p = axs[1, j].imshow(p, cmap=FIELD_CMAP, vmin=field_vmin, vmax=field_vmax, origin='lower', aspect='auto')
        im_e = axs[2, j].imshow(e, cmap=ERROR_CMAP, norm=LogNorm(vmin=err_vmin, vmax=err_vmax), origin='lower', aspect='auto')
        axs[0, j].set_title(name, fontsize=10)
        style_axis_with_dense_ticks(axs[0, j], t.shape[1], t.shape[0], n_ticks=6)
        style_axis_with_dense_ticks(axs[1, j], p.shape[1], p.shape[0], n_ticks=6)
        style_axis_with_dense_ticks(axs[2, j], e.shape[1], e.shape[0], n_ticks=6)
        if j == 0:
            axs[0, j].set_ylabel('True')
            axs[1, j].set_ylabel('Pred')
            axs[2, j].set_ylabel('|Error|')
        axs[2, j].set_xlabel('grid index')

    cbar_field = fig.colorbar(im_t, ax=axs[0, :].tolist() + axs[1, :].tolist(), fraction=0.018, pad=0.01)
    cbar_field.set_label('Speed magnitude')
    cbar_err = fig.colorbar(im_e, ax=axs[2, :].tolist(), fraction=0.018, pad=0.01)
    cbar_err.set_label('|Error|')
    fig.suptitle(
        f"{split_name} orthogonal projections | folder={s['folder']} frame={s['frame']} idx={s['idx']} rel-L2={s['rel_l2']:.3e}",
        fontsize=12,
    )
    save_fig(fig, f'qualitative_{save_tag}_orthogonal_planes.png')
    plt.show()


def plot_convergence_bundle():
    if len(HIST['epoch']) == 0:
        print('[skip] Convergence plot: history is empty')
        return

    fig, axs = plt.subplots(2, 2, figsize=(14, 9), constrained_layout=True)
    colors = {
        'train_lp': '#1f77b4',
        'train_rel': '#ff7f0e',
        'val_rel': '#2ca02c',
        'test_rel': '#d62728',
        'val_rmse': '#2ca02c',
        'test_rmse': '#d62728',
        'lr': '#9467bd',
    }

    axs[0, 0].plot(HIST['epoch'], HIST['train_rel_l2'], color=colors['train_rel'], linewidth=1.8, label='train rel-L2 (physical)')
    axs[0, 0].plot(HIST['epoch'], HIST['val_rel_l2'], color=colors['val_rel'], linewidth=1.8, label='val rel-L2 (physical)')
    if HAS_TEST:
        axs[0, 0].plot(HIST['epoch'], HIST['test_rel_l2'], color=colors['test_rel'], linewidth=1.8, label='test rel-L2 (physical)')
    style_curve_axis(axs[0, 0], 'Epoch', 'Relative L2')
    axs[0, 0].set_title('Convergence: Relative L2 (linear scale)')
    axs[0, 0].yaxis.set_major_formatter(FormatStrFormatter('%.3f'))
    axs[0, 0].legend()

    axs[0, 1].plot(HIST['epoch'], HIST['val_rmse'], color=colors['val_rmse'], linewidth=1.8, label='val RMSE (physical)')
    if HAS_TEST:
        axs[0, 1].plot(HIST['epoch'], HIST['test_rmse'], color=colors['test_rmse'], linewidth=1.8, label='test RMSE (physical)')
    style_curve_axis(axs[0, 1], 'Epoch', 'RMSE')
    axs[0, 1].set_title('Convergence: RMSE (linear scale)')
    axs[0, 1].legend()

    axs[1, 0].plot(HIST['epoch'], HIST['train_lp'], color=colors['train_lp'], linewidth=1.8, label='train Lp loss (normalized)')
    style_curve_axis(axs[1, 0], 'Epoch', 'Normalized loss')
    axs[1, 0].set_title('Training objective')
    axs[1, 0].legend()

    axs[1, 1].plot(HIST['epoch'], HIST['lr'], color=colors['lr'], linewidth=1.8, label='learning rate')
    style_curve_axis(axs[1, 1], 'Epoch', 'LR')
    axs[1, 1].set_title('Learning-rate schedule')
    axs[1, 1].legend()

    save_fig(fig, 'convergence_primary_bundle.png')
    plt.show()


def plot_end_snapshot_energy_gallery(candidate_dirs):
    if len(candidate_dirs) == 0:
        print('[skip] candidate preview dirs are empty')
        return

    previews = []
    for d in candidate_dirs:
        files = list_frame_files(d, expect_gridded=True)
        files = filter_valid_gridded_files(
            files,
            input_key=CFG['input_key'],
            expected_channels=CFG['input_channels'],
            label=f'{d.name} (preview)',
            max_report=2,
        )
        files = filter_by_min_frame(files, CFG['min_frame_test'], f'{d.name} (preview)')
        if len(files) == 0:
            continue
        fp = sorted(files, key=parse_frame_id)[-1]
        d_npz = np.load(fp)
        y = torch.tensor(np.asarray(d_npz['U_grid'], dtype=np.float32), dtype=torch.float32)
        speed = speed_from_velocity(y)
        xz = xz_max_projection(speed)
        previews.append({
            'folder': d.name,
            'frame': parse_frame_id(fp),
            'xz': xz,
        })

    if len(previews) == 0:
        print('[skip] no valid preview snapshots found')
        return

    vals = np.concatenate([p['xz'].reshape(-1) for p in previews])
    vmin = float(np.min(vals))
    vmax = float(np.max(vals))

    fig, axs = plt.subplots(1, len(previews), figsize=(4.2 * len(previews), 3.8), constrained_layout=True)
    if len(previews) == 1:
        axs = [axs]
    for i, p in enumerate(previews):
        im = axs[i].imshow(p['xz'].T, cmap=FIELD_CMAP, vmin=vmin, vmax=vmax, origin='lower', aspect='auto')
        axs[i].set_title(f"{p['folder']}\nend frame={p['frame']}", fontsize=10)
        style_axis_with_dense_ticks(axs[i], p['xz'].shape[0], p['xz'].shape[1], n_ticks=6)
        axs[i].set_xlabel('x index')
        if i == 0:
            axs[i].set_ylabel('z index')
    cbar = fig.colorbar(im, ax=axs, fraction=0.02, pad=0.01)
    cbar.set_label('True speed (XZ max over y)')
    fig.suptitle('End-time flow energy preview by folder (for holdout choice)', fontsize=12)
    save_fig(fig, 'test_folder_end_snapshot_preview.png')
    plt.show()
    for p in previews:
        print(f"[preview] folder={p['folder']} end_frame={p['frame']}")


print('Running folder preview + primary convergence/reconstruction diagnostics...')
plot_end_snapshot_energy_gallery(PREVIEW_DIRS)
plot_convergence_bundle()

test_meta = None
if HAS_TEST:
    test_meta = plot_timeline_3x4(
        TEST_DS,
        TEST_FILES,
        split_name='TEST (unseen folder)',
        min_frame=CFG['min_frame_test'],
        preferred_folder=CFG.get('preferred_test_folder'),
        save_tag='test',
    )
else:
    print('[warn] TEST split is empty: no unseen-folder timeline can be plotted.')

val_meta = plot_timeline_3x4(
    VAL_DS,
    VAL_FILES,
    split_name='VAL',
    min_frame=CFG['min_frame_trainval'],
    preferred_folder=CFG.get('preferred_val_folder'),
    save_tag='val',
)

train_meta = plot_timeline_3x4(
    TRAIN_DS,
    TRAIN_FILES,
    split_name='TRAIN',
    min_frame=CFG['min_frame_trainval'],
    preferred_folder=CFG.get('preferred_train_folder'),
    save_tag='train',
)

# 3D depiction through orthogonal max-projection planes for one late snapshot per split.
if test_meta is not None and len(test_meta['selected_indices']) > 0:
    plot_orthogonal_planes(TEST_DS, TEST_FILES, 'TEST', test_meta['selected_indices'][-1], save_tag='test')
if val_meta is not None and len(val_meta['selected_indices']) > 0:
    plot_orthogonal_planes(VAL_DS, VAL_FILES, 'VAL', val_meta['selected_indices'][-1], save_tag='val')
if train_meta is not None and len(train_meta['selected_indices']) > 0:
    plot_orthogonal_planes(TRAIN_DS, TRAIN_FILES, 'TRAIN', train_meta['selected_indices'][-1], save_tag='train')
# Out:
# [info] loaded best checkpoint for reporting: C:\Users\TCZ\Desktop\Neeraj\Flow-reconstruction-in-VPM-using-FNO-main\results\fno_randomdist_time_folder_3d_best_model.pt
# Running folder preview + primary convergence/reconstruction diagnostics...
# [warn] pair_1_fno_32 (preview): dropped 1 invalid files
#     - frame_0_grid.npz: non_finite_output
# [info] pair_1_fno_32 (preview) frame filter: kept 190/199 with frame >= 10
# [warn] pair_2_fno_32 (preview): dropped 1 invalid files
#     - frame_0_grid.npz: non_finite_output
# [info] pair_2_fno_32 (preview) frame filter: kept 191/200 with frame >= 10
# [warn] pair_3_fno_32 (preview): dropped 1 invalid files
#     - frame_0_grid.npz: non_finite_output
# [info] pair_3_fno_32 (preview) frame filter: kept 358/359 with frame >= 10
# [warn] pair_4_fno_32 (preview): dropped 1 invalid files
#     - frame_0_grid.npz: non_finite_output
# [info] pair_4_fno_32 (preview) frame filter: kept 198/199 with frame >= 10
# [warn] pair_5_fno_32 (preview): dropped 1 invalid files
#     - frame_0_grid.npz: non_finite_output
# [info] pair_5_fno_32 (preview) frame filter: kept 175/179 with frame >= 10
# [saved] C:\Users\TCZ\Desktop\Neeraj\Flow-reconstruction-in-VPM-using-FNO-main\results\fno_randomdist_time_folder_3d_test_folder_end_snapshot_preview.png
# [preview] folder=pair_1_fno_32 end_frame=199
# [preview] folder=pair_2_fno_32 end_frame=200
# [preview] folder=pair_3_fno_32 end_frame=1795
# [preview] folder=pair_4_fno_32 end_frame=995
# [preview] folder=pair_5_fno_32 end_frame=358
# [saved] C:\Users\TCZ\Desktop\Neeraj\Flow-reconstruction-in-VPM-using-FNO-main\results\fno_randomdist_time_folder_3d_convergence_primary_bundle.png
# [TEST (unseen folder)] timeline folder=pair_4_fno_32, selected idx=[6, 12, 18, 23]
# [note] idx = position in split list; frame = simulation timestep parsed from filename.
# [note] These panels use max projection over y (entire y-domain), so no active-y slice index is used.
# [saved] C:\Users\TCZ\Desktop\Neeraj\Flow-reconstruction-in-VPM-using-FNO-main\results\fno_randomdist_time_folder_3d_qualitative_test_timeline_3x4.png
#   TEST (unseen folder): folder=pair_4_fno_32 frame=280 idx=6 rel-L2=1.096e+00 file=frame_280_grid.npz
#   TEST (unseen folder): folder=pair_4_fno_32 frame=505 idx=12 rel-L2=1.104e+00 file=frame_505_grid.npz
#   TEST (unseen folder): folder=pair_4_fno_32 frame=825 idx=18 rel-L2=1.165e+00 file=frame_825_grid.npz
#   TEST (unseen folder): folder=pair_4_fno_32 frame=950 idx=23 rel-L2=1.129e+00 file=frame_950_grid.npz
# [VAL] timeline folder=pair_3_fno_32, selected idx=[25, 46, 69, 88]
# [note] idx = position in split list; frame = simulation timestep parsed from filename.
# [note] These panels use max projection over y (entire y-domain), so no active-y slice index is used.
# [saved] C:\Users\TCZ\Desktop\Neeraj\Flow-reconstruction-in-VPM-using-FNO-main\results\fno_randomdist_time_folder_3d_qualitative_val_timeline_3x4.png
#   VAL: folder=pair_3_fno_32 frame=605 idx=25 rel-L2=1.005e+00 file=frame_605_grid.npz
#   VAL: folder=pair_3_fno_32 frame=920 idx=46 rel-L2=9.977e-01 file=frame_920_grid.npz
#   VAL: folder=pair_3_fno_32 frame=1315 idx=69 rel-L2=1.003e+00 file=frame_1315_grid.npz
#   VAL: folder=pair_3_fno_32 frame=1725 idx=88 rel-L2=1.001e+00 file=frame_1725_grid.npz
# [TRAIN] timeline folder=pair_5_fno_32, selected idx=[45, 83, 127, 161]
# [note] idx = position in split list; frame = simulation timestep parsed from filename.
# [note] These panels use max projection over y (entire y-domain), so no active-y slice index is used.
# [saved] C:\Users\TCZ\Desktop\Neeraj\Flow-reconstruction-in-VPM-using-FNO-main\results\fno_randomdist_time_folder_3d_qualitative_train_timeline_3x4.png
#   TRAIN: folder=pair_5_fno_32 frame=100 idx=45 rel-L2=3.220e-02 file=frame_100_grid.npz
#   TRAIN: folder=pair_5_fno_32 frame=176 idx=83 rel-L2=4.035e-02 file=frame_176_grid.npz
#   TRAIN: folder=pair_5_fno_32 frame=264 idx=127 rel-L2=3.896e-02 file=frame_264_grid.npz
#   TRAIN: folder=pair_5_fno_32 frame=332 idx=161 rel-L2=4.370e-02 file=frame_332_grid.npz
# [saved] C:\Users\TCZ\Desktop\Neeraj\Flow-reconstruction-in-VPM-using-FNO-main\results\fno_randomdist_time_folder_3d_qualitative_test_orthogonal_planes.png
# [saved] C:\Users\TCZ\Desktop\Neeraj\Flow-reconstruction-in-VPM-using-FNO-main\results\fno_randomdist_time_folder_3d_qualitative_val_orthogonal_planes.png
# [saved] C:\Users\TCZ\Desktop\Neeraj\Flow-reconstruction-in-VPM-using-FNO-main\results\fno_randomdist_time_folder_3d_qualitative_train_orthogonal_planes.png

# %%
# =========================
# Optional diagnostics (disabled by default)
# =========================
if CFG.get('enable_optional_plots', False):
    print('[info] Optional distribution/parity diagnostics can be added here when needed.')
else:
    print('[skip] Optional distribution/parity diagnostics disabled to keep the primary workflow focused.')
# Out:
# [skip] Optional distribution/parity diagnostics disabled to keep the primary workflow focused.

# %%
# =========================
# Snapshot panel note
# =========================
print('[info] Reconstruction timelines are now generated in snippet 6 as 3x4 panels for TEST/VAL/TRAIN.')
print('[info] Each 3x4 panel uses one folder per split and four distant time snapshots from the same dataset.')
# Out:
# [info] Reconstruction timelines are now generated in snippet 6 as 3x4 panels for TEST/VAL/TRAIN.
# [info] Each 3x4 panel uses one folder per split and four distant time snapshots from the same dataset.

# %%
# =========================
# Optional misc diagnostics placeholder
# =========================
print('[skip] Data-hunger diagnostics are disabled for now to keep the primary workflow focused.')
print("[info] Set CFG['enable_optional_plots']=True and re-add this cell if you want data-hunger runs later.")
# Out:
# [skip] Data-hunger diagnostics are disabled for now to keep the primary workflow focused.
# [info] Set CFG['enable_optional_plots']=True and re-add this cell if you want data-hunger runs later.

# %%
# =========================
# Optional sweep diagnostics placeholder
# =========================
print('[skip] Sensitivity sweeps are disabled for now to avoid confusion with the primary reconstruction workflow.')
print("[info] Hidden-channel sweep compares quick retrains with modified configs; it does not claim your main run used all sweep values.")
# Out:
# [skip] Sensitivity sweeps are disabled for now to avoid confusion with the primary reconstruction workflow.
# [info] Hidden-channel sweep compares quick retrains with modified configs; it does not claim your main run used all sweep values.

# %%
# =========================
# Optional data profile placeholder
# =========================
print('[skip] Standalone 3D data-profile scatter plots are disabled for now.')
print('[info] 3D reconstruction interpretation is now centered in snippet 6 via timeline and orthogonal-plane views.')
# Out:
# [skip] Standalone 3D data-profile scatter plots are disabled for now.
# [info] 3D reconstruction interpretation is now centered in snippet 6 via timeline and orthogonal-plane views.

# %%
# =========================
# Optional IO flow demo placeholder
# =========================
print('[skip] The separate IO flow demo is disabled for now to avoid duplicate visuals.')
print('[info] Use snippet 6 outputs: convergence bundle, 3x4 timelines, and orthogonal-plane reconstructions.')
# Out:
# [skip] The separate IO flow demo is disabled for now to avoid duplicate visuals.
# [info] Use snippet 6 outputs: convergence bundle, 3x4 timelines, and orthogonal-plane reconstructions.
